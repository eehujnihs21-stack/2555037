# %% [markdown]
# <a href="https://colab.research.google.com/github/eehujnihs21-stack/2555037/blob/main/0320_02_class_initialize_attributes_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **<font color='blue'> Class = Chef**
# > ### **Understanding Class와 속성, 인스터스**

# %%
class Cheff:
    pass

# %% [markdown]
# - **Cheff** : without parentheses is a class definition.
# >> It defines a blueprint for creating objects. Cheff is **an empty class with no attributes or methods defined.** It's just a shell that can be used to create instances of the Cheff class.
#
# - **Cheff()**:
# >> Cheff() with parentheses is used **to create an instance (object) of the Cheff class**. When you call Cheff(), it creates a new object based on the blueprint defined by the Cheff class. This object can then be used to store data (attributes) and perform actions (methods) defined within the class.

# %%
Cheff
# Out:
# __main__.Cheff

# %%
__name__ == '__main__'
# Out:
# True

# %%
Cheff()

# %% [markdown]
# #### **함수와 다른 점**

# %%
def hello():
    print('Hi Hello')

# %%
hello
# Out:
# <function __main__.hello()>

# %%
hello()
# Out:
# Hi Hello

# %%
Cheff.id = '01'  # Cheff 클래스 자체에 새로운 클래스 속성을 추가

# %%
Cheff.id
# Out:
# '01'

# %%
Cheff.name = 'Tom'
Cheff.name
# Out:
# 'Tom'

# %%
Cheff
# Out:
# __main__.Cheff

# %%
# 인스턴스 생성
c1 = Cheff()
c2 = Cheff()

print(c1.name) # 출력: Tom
print(c2.name) # 출력: Tom
# Out:
# Tom
# Tom

# %% [markdown]
# ### **Class**
# >> **class Cheff:**
# >>> **pass**
#
# >> **user_1 = Cheff()**
#
# > ##### **1. 두 개의 객체가 생성**
# > ##### **2. Cheff라는 클라스이름은 클래스 객체를 바인딩(Binding)**
# > ##### **3. user_1 변수는 Cheff 클래스 타입의 객체를 바인딩**
# > ##### **<font color='blue'>4. 클래스와 객체가 각자 고유의 메모리 공간을 갖는다**
#
# - 클래스는 붕어빵틀(Cheff)로 객체(user_1)는 붕어빵틀로부터 구어진 붕어빵

# %%
class Cheff:
    pass

# %%
user_1 = Cheff()       # Class를 객체화

# %%
id(Cheff())
# Out:
# 137565424634144

# %%
id(Cheff)
# Out:
# 699792896

# %%
id(user_1)
# Out:
# 137565424636064

# %%
user_2 = Cheff()
id(user_2)
# Out:
# 137565434623280

# %% [markdown]
# **Why the Memory Addresses are Different:**
# - **Temporary Instance (id(Cheff())):**
# > Each call to Cheff() creates a new, unique instance of the Cheff class.
# When you call id(Cheff()), a new instance is created temporarily for the id function call, and this instance is not stored or referenced after the id call.
# Since it is a new instance, it has a unique memory address each time you call Cheff().
#
# - **Persistent Instance (id(user_1)):**
# > When you call user_1 = Cheff(), an instance of Cheff is created and stored in the variable user_1.
# The id(user_1) call retrieves the memory address of this specific, persistent instance.

# %%
# user_1 인스턴스에 새로운 인스턴스 속성을 추가
# user의 attributes 'id'를 생성하고 attributes의 값(vlaue)을 '001'이라고 함

user_1.id = '001'

# %%
user_1.username = 'tom'

# %%
user_1.marry = True

# %%
user_1.age = 25

# %%
print(user_1.id)
# Out:
# 001

# %%
print(user_1.username)
# Out:
# tom

# %%
print(user_1.age)
# Out:
# 25

# %%
print(user_1.marry)
# Out:
# True

# %% [markdown]
# 일반적으로는 클래스 내부에 변수를 미리 선언하지만, 파이썬에서는 클래스를 정의한 후에도 외부에서 마치 포스트잇을 붙이듯이 새로운 속성을 추가할 수 있습니다.
#
#
# 💡 주의할 점
# 실무에서는 이 방식보다는 __init__ 메서드를 사용해 객체를 만들 때 값을 넣어주는 방식을 권장합니다. 클래스 자체에 값을 고정해버리면 나중에 요리사마다 이름을 다르게 관리하기가 까다로워질 수 있거든요.
#
# 혹시 이 Cheff 클래스를 활용해 개별 요리사 객체마다 다른 아이디와 이름을 부여하는 코드로 발전시켜 볼까요? 원하신다면 __init__을 사용한 정석적인 코드를 만들어 봅시다.

# %% [markdown]
# #### **Chef를 쉽게 만드는 방법, 붕어빵 처럼 찍어내기**
# ### **<font color='blue'>Object = Tom, Mary, Henry, Magaret, Edward**
# <img src= 'https://img.freepik.com/free-vector/cook-collection-concept_23-2148514280.jpg?w=996&t=st=1690469366~exp=1690469966~hmac=1e8376fab19963197a896074cbd6f00d3f5a6e79360a9cd532bc4e5b6d6d8839' width = 700 height= 400>
#
#
# ## **<font color='blue'> chef = Chef(), object = Class()**
# ## **객체(chef)를 만들고 속성(attributes)과 메소드(method) 생성하기**

# %% [markdown]
# ## **1. 속성(attributes)**

# %% [markdown]
# - **user(cheff)가 수천 명이면 ?? 난감하네**
# ## Constructor
# ### Initialize(in·i·tial·ize/iˈniSHəˌlīz/) verb 가 필요
# #### COMPUTING
# - 1. set to the value or put in the condition appropriate to the start of an operation.
# "the counter is initialized to one"
# - 2. format (a computer disk).

# %% [markdown]
# > ### Constructor
# ---
# ### **class Car:**
# > **def __init __ (self):**
#
# >   - #### Initialize attributes
#
# <img src='https://pynative.com/wp-content/uploads/2021/07/create_declare_instance_variable.png'>
#
# >> ### **클래스에 속성을 추가하면 해당 클래스의 모든 인스턴스가 이 새로운 속성을 공유**
# >> ### **즉, id와 name 속성은 모든 Cheff 인스턴스에 적용**

# %%
class User:
    pass

# %%
class User:
    def __init__(self, user_id, user_name):
        self.id = user_id
        self.name = user_name

user_1 = User('001', 'Tom')
user_2 = User('002', 'Jerry')

# %%
# prompt: 100명의 user를 만들려면

users = []
for i in range(100):
  user_id = str(i).zfill(3)
  user_name = f"user_{i}"
  user = User(user_id, user_name)
  users.append(user)

# %%
users[1].id
# Out:
# '001'

# %%
', '.join([users[i].id for i in range(100)])
# Out:
# '000, 001, 002, 003, 004, 005, 006, 007, 008, 009, 010, 011, 012, 013, 014, 015, 016, 017, 018, 019, 020, 021, 022, 023, 024, 025, 026, 027, 028, 029, 030, 031, 032, 033, 034, 035, 036, 037, 038, 039, 040, 041, 042, 043, 044, 045, 046, 047, 048, 049, 050, 051, 052, 053, 054, 055, 056, 057, 058, 059, 060, 061, 062, 063, 064, 065, 066, 067, 068, 069, 070, 071, 072, 073, 074, 075, 076, 077, 078, 079, 080, 081, 082, 083, 084, 085, 086, 087, 088, 089, 090, 091, 092, 093, 094, 095, 096, 097, 098, 099'

# %%
', '.join([users[i].name for i in range(100)])
# Out:
# 'user_0, user_1, user_2, user_3, user_4, user_5, user_6, user_7, user_8, user_9, user_10, user_11, user_12, user_13, user_14, user_15, user_16, user_17, user_18, user_19, user_20, user_21, user_22, user_23, user_24, user_25, user_26, user_27, user_28, user_29, user_30, user_31, user_32, user_33, user_34, user_35, user_36, user_37, user_38, user_39, user_40, user_41, user_42, user_43, user_44, user_45, user_46, user_47, user_48, user_49, user_50, user_51, user_52, user_53, user_54, user_55, user_56, user_57, user_58, user_59, user_60, user_61, user_62, user_63, user_64, user_65, user_66, user_67, user_68, user_69, user_70, user_71, user_72, user_73, user_74, user_75, user_76, user_77, user_78, user_79, user_80, user_81, user_82, user_83, user_84, user_85, user_86, user_87, user_88, user_89, user_90, user_91, user_92, user_93, user_94, user_95, user_96, user_97, user_98, user_99'

# %%
user_1.id
# Out:
# '001'

# %%
user_2.name
# Out:
# 'Jerry'

# %%
class User:
    def __init__(self, user_id, user_name, user_age):
        self.id = user_id
        self.name = user_name
        self.age = user_age

user_1 = User('001', 'Tom', 35)
user_2 = User('002', 'Jerry', 33)

# %%
user_1.age
# Out:
# 35

# %% [markdown]
# ## **2. 메소드(method)**
#
# >> ### Cheff 대신 차량을 가정하여 Class를 만들어 보자
# ---
# ### **class Car:**
# > **def __init __ (self):**
# >   - ##### Initialize attributes (seats = 5)
# >   - **HAS (Attiributes)**
#
# > **def enter_race_mode():**
# >   - ##### chage attributes (seats = 1) for entering F1
# >   - **Does (Method, Change the attributes)**
#
#
# ---
#
# - car = Carbluprint()라면 자동차의 좌석수, 문짝 개수 등의 기본 속성을 정의
# - F1에 출전하려면 좌석을 1개로 줄여야 한다(method)
#
#
# <img src='https://media.istockphoto.com/id/1263896499/ko/%EC%82%AC%EC%A7%84/%EC%9D%BC%EB%AA%B0%EC%97%90-%EA%B7%B8%EB%9E%9C%EB%93%9C-%EC%8A%A4%ED%83%A0%EB%93%9C-%EA%B7%BC%EC%B2%98-%EA%B2%BD%EB%A7%88%EC%9E%A5%EC%97%90%EC%84%9C-%EB%B9%A0%EB%A5%B4%EA%B2%8C-%EC%9D%B4%EB%8F%99-%EA%B2%BD%EC%A3%BC-%EC%9E%90%EB%8F%99%EC%B0%A8.webp?b=1&s=170667a&w=0&k=20&c=Yi_YSedv8Cebb9AbZzFYaLEx0bzW4pYqzA2MD5yQHN0='>

# %%
class Car:
    # 1. 생성자: 객체가 만들어질 때 호출되는 함수
    def __init__(self, brand, model, color):
        self.brand = brand  # 브랜드
        self.model = model  # 모델명
        self.color = color  # 색상
        self.speed = 0      # 현재 속도 (기본값 0)

    # 2. 메서드: 자동차의 동작 (가속)
    def accelerate(self, amount):
        self.speed += amount
        print(f"{self.model}이(가) {amount}km/h 가속하여 현재 {self.speed}km/h입니다.")

    # 3. 메서드: 자동차의 동작 (정지)
    def stop(self):
        self.speed = 0
        print(f"{self.model}이(가) 멈췄습니다.")

# %%
# 'my_car'라는 실제 자동차 객체 생성
my_car = Car("Hyundai", "Ionic 6", "White")

# 'your_car'라는 또 다른 자동차 객체 생성
your_car = Car("Tesla", "Model 3", "Black")

# 각 자동차의 정보 출력
print(f"내 차는 {my_car.brand} {my_car.model}입니다.")
# 출력: 내 차는 Hyundai Ionic 6입니다.

# 자동차 동작시키기
my_car.accelerate(50)  # Ionic 6이 50km/h로 달립니다.
your_car.accelerate(80) # Model 3는 80km/h로 달립니다.
# Out:
# 내 차는 Hyundai Ionic 6입니다.
# Ionic 6이(가) 50km/h 가속하여 현재 50km/h입니다.
# Model 3이(가) 80km/h 가속하여 현재 80km/h입니다.

# %% [markdown]
# ## **과제 1. faker를 사용하여 1000명의 데이터를 class를 이용하여 만들어라**
#
# - [click faker](https://faker.readthedocs.io/en/master/)

# %%
# !pip install faker
from faker import Faker

# 1. Faker 초기화 (한국어 설정)
fake = Faker('ko_KR')

# 2. 사용자 클래스 정의
class User:
    def __init__(self):
        self.name = fake.name()          # 이름
        self.email = fake.email()        # 이메일
        self.address = fake.address()    # 주소
        self.job = fake.job()            # 직업
        self.phone = fake.phone_number() # 전화번호

    def __repr__(self):
        return f"User(이름: {self.name}, 직업: {self.job})"

# 3. 1,000명의 데이터 생성
user_list = [User() for _ in range(1000)]

# 4. 결과 확인 (상위 5명만 출력)
print(f"총 생성된 데이터 수: {len(user_list)}명")
for user in user_list[:1000]:
    print(f"이름: {user.name} | 이메일: {user.email} | 직업: {user.job}")
# Out:
# Collecting faker
#   Downloading faker-40.19.1-py3-none-any.whl.metadata (16 kB)
# Downloading faker-40.19.1-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 24.9 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-40.19.1
# 총 생성된 데이터 수: 1000명
# 이름: 김서연 | 이메일: yeongsungang@example.net | 직업: 조세행정 사무원
# 이름: 김미경 | 이메일: oi@example.com | 직업: 대학 교육조교
# 이름: 차지은 | 이메일: ieungyeong@example.org | 직업: 가수 및 성악가
# 이름: 장민수 | 이메일: myeongja32@example.com | 직업: 치과기공사
# 이름: 박예준 | 이메일: minjae47@example.org | 직업: 치과기공사
# 이름: 김순옥 | 이메일: bagyeweon@example.com | 직업: 부동산 컨설턴트 및 중개인
# 이름: 이수민 | 이메일: jihye66@example.com | 직업: 상품중개인 및 경매사
# 이름: 김춘자 | 이메일: yujingim@example.org | 직업: 건설 및 광업기계 설치 및 정비원
# 이름: 문성민 | 이메일: jimijeong@example.net | 직업: 제분 및 도정 관련 기계 조작원
# 이름: 송민지 | 이메일: junhyeog20@example.net | 직업: 조경원
# 이름: 한서영 | 이메일: vgim@example.com | 직업: 안경사
# 이름: 박은경 | 이메일: gweonhayun@example.net | 직업: 광원/채석원 및 석재 절단원
# 이름: 박예지 | 이메일: yeongsun84@example.org | 직업: 보험 설계사 및 간접투자증권 판매인
# 이름: 이영길 | 이메일: hyeonsugmun@example.org | 직업: 시각 디자이너
# 이름: 이성현 | 이메일: hyeonu05@example.com | 직업: 건축 도장공
# 이름: 김미영 | 이메일: jungsuryu@example.com | 직업: 직업 운동선수
# 이름: 나정웅 | 이메일: gujeongsun@example.org | 직업: 계기 검침원 및 가스점검원
# 이름: 이명자 | 이메일: iseonghyeon@example.org | 직업: 육아 도우미
# 이름: 이재호 | 이메일: seoseongjin@example.net | 직업: 직업상담사 및 취업 알선원
# 이름: 박정웅 | 이메일: bagseongsu@example.net | 직업: 부동산 컨설턴트 및 중개인
# 이름: 이명숙 | 이메일: iboram@example.com | 직업: 재활용 처리 및 소각로 조작원
# 이름: 김하윤 | 이메일: seonghoseo@example.net | 직업: 해외 영업원
# 이름: 김영희 | 이메일: bagyeongsug@example.net | 직업: 치과기공사
# 이름: 이순옥 | 이메일: jaehyeon78@example.net | 직업: 재단사
# 이름: 손성호 | 이메일: jinho72@example.org | 직업: 경비원
# 이름: 최상호 | 이메일: yeongil06@example.net | 직업: 국악 및 전통예능인
# 이름: 최현우 | 이메일: doyun31@example.com | 직업: 육류/어패류 및 낙농품 가공 기계조작원
# 이름: 김아름 | 이메일: isubin@example.net | 직업: 관세사
# 이름: 권영호 | 이메일: sujin92@example.com | 직업: 자동차 조립원
# 이름: 최병철 | 이메일: ri@example.com | 직업: 안내 / 접수 사무원 및 전화교환원
# 이름: 김민지 | 이메일: jiweon40@example.net | 직업: 운송장비 조립원
# 이름: 최수빈 | 이메일: misug59@example.org | 직업: 금속기계부품 조립원
# 이름: 한춘자 | 이메일: jongsu26@example.net | 직업: 선박 및 열차 객실승무원
# 이름: 김영희 | 이메일: gimseonghyeon@example.org | 직업: 기타 사무원
# 이름: 김진호 | 이메일: kgim@example.net | 직업: 조적공 및 석재 부설원
# 이름: 박지연 | 이메일: nbag@example.net | 직업: 금속가공 기계조작원
# 이름: 한민수 | 이메일: sanghyeon12@example.com | 직업: 광원/채석원 및 석재 절단원
# 이름: 김지훈 | 이메일: rgim@example.com | 직업: 청소원
# 이름: 김지영 | 이메일: gimminseog@example.org | 직업: 승강기 설치 및 정비원
# 이름: 한성현 | 이메일: cunjaha@example.org | 직업: 치과 의사
# 이름: 이수진 | 이메일: minji04@example.net | 직업: 지휘자/작곡가 및 연주가
# 이름: 최미숙 | 이메일: ajo@example.org | 직업: 환경공학 시험원
# 이름: 이영일 | 이메일: sbag@example.com | 직업: 결혼 상담원 및 웨딩플래너
# 이름: 박예은 | 이메일: sugjai@example.net | 직업: 여행상품 개발자
# 이름: 이예준 | 이메일: seocunja@example.com | 직업: 기타 전기/전자기기 설치 및 수리원
# 이름: 박지은 | 이메일: ogsun36@example.net | 직업: 사서 및 기록물관리사
# 이름: 송숙자 | 이메일: jeonghyi79@example.com | 직업: 컴퓨터시스템 설계 및 분석가
# 이름: 차명숙 | 이메일: seoyeon21@example.net | 직업: 보험 심사원 및 사무원
# 이름: 박우진 | 이메일: yunyeongil@example.org | 직업: 가구 제조 및 수리원
# 이름: 김영일 | 이메일: sunjai@example.net | 직업: 금속 / 재료공학 연구원 및 기술자
# 이름: 김보람 | 이메일: sujin27@example.com | 직업: 계기 검침원 및 가스점검원
# 이름: 이영환 | 이메일: sugjagweon@example.net | 직업: 자동차 정비원
# 이름: 한혜진 | 이메일: zi@example.org | 직업: 기술 및 기능계 강사
# 이름: 김지현 | 이메일: seoyeongi@example.org | 직업: 국가/지방 및 공공행정 사무원
# 이름: 오현지 | 이메일: yeongjingim@example.net | 직업: 성직자
# 이름: 박승현 | 이메일: sugjagweon@example.org | 직업: 세탁원 및 다림질원
# 이름: 김경수 | 이메일: hongjungsu@example.org | 직업: 임상병리사
# 이름: 이지은 | 이메일: boramyun@example.com | 직업: 환경 미화원 및 재활용품 수거원
# 이름: 배도현 | 이메일: gimsubin@example.net | 직업: 곡식작물 재배원
# 이름: 이민석 | 이메일: gyeongja21@example.org | 직업: 지휘자/작곡가 및 연주가
# 이름: 노준혁 | 이메일: ijeongja@example.org | 직업: 기술 영업원
# 이름: 서서준 | 이메일: gimgyeongsu@example.com | 직업: 치과위생사
# 이름: 안서윤 | 이메일: yeweon00@example.com | 직업: 혼례 종사원
# 이름: 장민수 | 이메일: ogwag@example.org | 직업: 정부행정 관리자
# 이름: 최숙자 | 이메일: iyeongsug@example.com | 직업: 배우 및 모델
# 이름: 양영수 | 이메일: seongmini@example.com | 직업: 경영지원 관리자
# 이름: 김선영 | 이메일: hyeonjun39@example.net | 직업: 패스트푸드원
# 이름: 김영미 | 이메일: gimeungyeong@example.net | 직업: 제품 및 광고 영업원
# 이름: 강준호 | 이메일: seunghyeon01@example.com | 직업: 노점 및 이동 판매원
# 이름: 박미영 | 이메일: ki@example.net | 직업: 기자 및 논설위원
# 이름: 박하윤 | 이메일: yeonghwanhan@example.org | 직업: 택배원
# 이름: 김성훈 | 이메일: sryu@example.com | 직업: 전기 부품 및 제품제조 기계조작원
# 이름: 박경수 | 이메일: ogsun35@example.com | 직업: 계기 검침원 및 가스점검원
# 이름: 이정훈 | 이메일: baegyeongja@example.org | 직업: 판금기 조작원
# 이름: 황정수 | 이메일: hansujin@example.com | 직업: 단열공
# 이름: 박현지 | 이메일: jongsu50@example.net | 직업: 자연과학 시험원
# 이름: 김채원 | 이메일: geonu10@example.com | 직업: 의지보조기기사
# 이름: 이현주 | 이메일: kcoe@example.org | 직업: 냉/난방 관련 설비 조작원
# 이름: 김현준 | 이메일: ibag@example.net | 직업: 안경사
# 이름: 김지현 | 이메일: man@example.org | 직업: 가사 도우미
# 이름: 김승현 | 이메일: haeun50@example.org | 직업: 직업 운동선수
# 이름: 유민지 | 이메일: gyeongsug63@example.net | 직업: 영관급 이상
# 이름: 백유진 | 이메일: jiyeong95@example.com | 직업: 가구 제조 및 수리원
# 이름: 강지영 | 이메일: gimgyeongsu@example.org | 직업: 정부행정 관리자
# 이름: 고승민 | 이메일: seonyeong86@example.net | 직업: 금융관련 사무원
# 이름: 김지혜 | 이메일: jeongja91@example.org | 직업: 기업고위임원
# 이름: 남정웅 | 이메일: seonghun97@example.com | 직업: 항공기 조종사
# 이름: 김예지 | 이메일: donghyeon07@example.net | 직업: 기타 주방장 및 조리사
# 이름: 송은주 | 이메일: bagdohyeon@example.com | 직업: 국악 및 전통예능인
# 이름: 주경숙 | 이메일: guyeongsu@example.org | 직업: 기타 의료/복지 관련 서비스 종사원
# 이름: 우지은 | 이메일: dha@example.net | 직업: 가구조립원
# 이름: 한승민 | 이메일: boram94@example.net | 직업: 항공기 조종사
# 이름: 류지혜 | 이메일: ncoe@example.net | 직업: 전기/전자 및 기계 공학 시험원
# 이름: 조민재 | 이메일: pbag@example.org | 직업: 광원/채석원 및 석재 절단원
# 이름: 나상호 | 이메일: yeongsug49@example.org | 직업: 펄프 및 종이 제조장치 조작원
# 이름: 차유진 | 이메일: myeongsuggweon@example.org | 직업: 기타 사육관련 종사원
# 이름: 박도현 | 이메일: gimmiyeong@example.net | 직업: 상품 대여원
# 이름: 송현준 | 이메일: msong@example.net | 직업: 자동차 영업원
# 이름: 이예준 | 이메일: jeongnam26@example.org | 직업: 도배공 및 유리 부착원
# 이름: 류경숙 | 이메일: baghyeonu@example.org | 직업: 선박 정비원
# 이름: 안주원 | 이메일: anjiu@example.org | 직업: 운송장비 조립원
# 이름: 장보람 | 이메일: seongho45@example.com | 직업: 컴퓨터 하드웨어 기술자 및 연구원
# 이름: 강민서 | 이메일: eunjisong@example.org | 직업: 가구조립원
# 이름: 오숙자 | 이메일: hajunseo@example.org | 직업: 번역가
# 이름: 김지영 | 이메일: mijeong98@example.net | 직업: 승강기 설치 및 정비원
# 이름: 류성현 | 이메일: sunog93@example.org | 직업: 주차 관리원 및 안내원
# 이름: 이중수 | 이메일: dseong@example.net | 직업: 화물열차 차장 및 관련 종사원
# 이름: 김민재 | 이메일: yangminseog@example.net | 직업: 방수공
# 이름: 최은정 | 이메일: minjun46@example.org | 직업: 기타 목재 및 종이 관련 기계조작원
# 이름: 박옥순 | 이메일: mgim@example.net | 직업: 정부행정 관리자
# 이름: 김영일 | 이메일: wu@example.net | 직업: 승강기 설치 및 정비원
# 이름: 윤영식 | 이메일: jeongsun74@example.com | 직업: 콘크리트공
# 이름: 이승현 | 이메일: uca@example.org | 직업: 방수공
# 이름: 박서현 | 이메일: ahan@example.net | 직업: 자연과학 시험원
# 이름: 이미경 | 이메일: cunjagim@example.net | 직업: 데이터베이스 개발자
# 이름: 이준혁 | 이메일: ki@example.org | 직업: 노점 및 이동 판매원
# 이름: 이승민 | 이메일: dohyeongim@example.net | 직업: 장기 부사관 및 준위
# 이름: 김영순 | 이메일: eungyeong69@example.org | 직업: 애완동물 미용사
# 이름: 박도윤 | 이메일: sinhyeonju@example.net | 직업: 검표원
# 이름: 김지혜 | 이메일: mseo@example.net | 직업: 마술사 및 기타 문화/ 예술 관련 종사자
# 이름: 장도현 | 이메일: jiyeongbag@example.org | 직업: 도장기 조작원
# 이름: 이우진 | 이메일: minjaegim@example.org | 직업: 플라스틱제품 생산기 조작원
# 이름: 박영길 | 이메일: hyeonjeongjang@example.com | 직업: 스포츠 및 레크레이션 강사
# 이름: 박정순 | 이메일: seoyeon33@example.com | 직업: 애완동물 미용사
# 이름: 박민수 | 이메일: wbag@example.com | 직업: 내선전공
# 이름: 이종수 | 이메일: coehyejin@example.com | 직업: 배관 세정원 및 방역원
# 이름: 이선영 | 이메일: yeongsungim@example.org | 직업: 양식 주방장 및 조리사
# 이름: 장지훈 | 이메일: jiu52@example.com | 직업: 정보통신관련 관리자
# 이름: 김지민 | 이메일: oan@example.com | 직업: 약사 및 한약사
# 이름: 김정희 | 이메일: ai@example.org | 직업: 유리제조 및 가공기 조작원
# 이름: 한영순 | 이메일: ti@example.org | 직업: 기타 공학관련 기술자 및 시험원
# 이름: 이현정 | 이메일: cunjagim@example.com | 직업: 어부 및 해녀
# 이름: 곽영미 | 이메일: yeongsig84@example.com | 직업: 텔레마케터
# 이름: 윤순자 | 이메일: yunjongsu@example.net | 직업: 식품 및 담배 등급원
# 이름: 강준영 | 이메일: eunjeong74@example.org | 직업: 가축 사육 종사원
# 이름: 강미영 | 이메일: agang@example.org | 직업: 경량 철골공
# 이름: 이승현 | 이메일: yeeunryu@example.net | 직업: 비서
# 이름: 김정훈 | 이메일: iyeongjin@example.com | 직업: 음료 제조관련 기계 조작원
# 이름: 성아름 | 이메일: oi@example.org | 직업: 기타 석유 및 화학물 가공장치 조작원
# 이름: 최지아 | 이메일: lbag@example.com | 직업: 육류/어패류 및 낙농품 가공 기계조작원
# 이름: 홍지후 | 이메일: oyejun@example.net | 직업: 전기 및 전자 설비 조작원
# 이름: 박정훈 | 이메일: pi@example.org | 직업: 청원 경찰
# 이름: 허준영 | 이메일: ssong@example.com | 직업: 숙박시설 서비스원
# 이름: 박영희 | 이메일: gwangsu47@example.net | 직업: 육류/어패류 및 낙농품 가공 기계조작원
# 이름: 최보람 | 이메일: agim@example.com | 직업: 사회복지사
# 이름: 김승현 | 이메일: gimhyeonjeong@example.net | 직업: 김치 및 밑반찬 제조 종사원
# 이름: 장민준 | 이메일: hyeonji79@example.net | 직업: 위관급
# 이름: 이지우 | 이메일: jeongsuggang@example.org | 직업: 단조원
# 이름: 심지은 | 이메일: jaehobag@example.net | 직업: 내선전공
# 이름: 김지은 | 이메일: junhocoe@example.org | 직업: 제품 생산관련 관리자
# 이름: 유영희 | 이메일: jongsuseo@example.org | 직업: 인쇄기 조작원
# 이름: 백춘자 | 이메일: sugja99@example.org | 직업: 강구조물 가공원 및 건립원
# 이름: 장경숙 | 이메일: yeongsuni@example.org | 직업: 섀시 조립 및 설치원
# 이름: 송성진 | 이메일: hyeonuhan@example.com | 직업: 전자 부품 및 제품 제조 기계조작원
# 이름: 김선영 | 이메일: jaehohong@example.com | 직업: 용접원
# 이름: 이하윤 | 이메일: iseojun@example.com | 직업: 계기 검침원 및 가스점검원
# 이름: 백재호 | 이메일: sonhyeonjeong@example.net | 직업: 간호사
# 이름: 이우진 | 이메일: ji@example.net | 직업: 임상 심리사 및 기타 치료사
# 이름: 김은경 | 이메일: sujin25@example.org | 직업: 경량 철골공
# 이름: 김아름 | 이메일: gimhyeonsug@example.net | 직업: 주조원
# 이름: 최광수 | 이메일: eungyeongi@example.org | 직업: 기타 식품가공관련 종사원
# 이름: 최정숙 | 이메일: gimcunja@example.org | 직업: 가구조립원
# 이름: 김명자 | 이메일: junhyeog92@example.org | 직업: 물리 및 작업 치료사
# 이름: 곽영자 | 이메일: seoyeongim@example.com | 직업: 석유 및 천연가스제조 관련 제어장치 조작원
# 이름: 김채원 | 이메일: jgim@example.org | 직업: 펄프 및 종이 제조장치 조작원
# 이름: 김도현 | 이메일: dohyeon72@example.org | 직업: 가구조립원
# 이름: 이서영 | 이메일: bageunseo@example.net | 직업: 일반기계 조립원
# 이름: 이명자 | 이메일: cseo@example.com | 직업: 단조원
# 이름: 홍경수 | 이메일: xgu@example.net | 직업: 기타 기술영업 및 중개 관련 종사자
# 이름: 이민준 | 이메일: di@example.com | 직업: 소년보호관 및 교도관
# 이름: 최정웅 | 이메일: yeonghyibaeg@example.com | 직업: 소방관
# 이름: 박수빈 | 이메일: byeongceolcoe@example.com | 직업: 목재 가공관련 기계 조작원
# 이름: 이서현 | 이메일: dji@example.org | 직업: 자산 운용가
# 이름: 강영미 | 이메일: jongsu16@example.org | 직업: 기업고위임원
# 이름: 장보람 | 이메일: baeggyeongja@example.org | 직업: 아나운서 및 리포터
# 이름: 윤동현 | 이메일: migyeongbae@example.net | 직업: 국악 및 전통예능인
# 이름: 장영수 | 이메일: sgim@example.org | 직업: 조세행정 사무원
# 이름: 신명자 | 이메일: jgim@example.com | 직업: 생명과학 연구원
# 이름: 민서영 | 이메일: jeongsu92@example.net | 직업: 임산물채취 및 기타 임업 관련 종사원
# 이름: 이정호 | 이메일: isanghun@example.com | 직업: 경기심판 및 경기기록원
# 이름: 안지훈 | 이메일: yeongjingim@example.net | 직업: 금속기계부품 조립원
# 이름: 박주원 | 이메일: kan@example.org | 직업: 관세사
# 이름: 윤광수 | 이메일: xi@example.org | 직업: 건설자재 시험원
# 이름: 서성진 | 이메일: gimeunju@example.com | 직업: 직업 운동선수
# 이름: 이춘자 | 이메일: vseo@example.com | 직업: 병무행정 사무원
# 이름: 김정자 | 이메일: doyun58@example.net | 직업: 보조 교사 및 기타 교사
# 이름: 박영순 | 이메일: isunja@example.com | 직업: 주유원
# 이름: 조지아 | 이메일: iseunghyeon@example.org | 직업: 경비원
# 이름: 이현지 | 이메일: kgim@example.com | 직업: 방사선사
# 이름: 이성훈 | 이메일: jieun74@example.org | 직업: 음식서비스관련 관리자
# 이름: 박지현 | 이메일: haeun03@example.net | 직업: 세탁원 및 다림질원
# 이름: 홍민준 | 이메일: eunjeong64@example.org | 직업: 특수교육 교사
# 이름: 이건우 | 이메일: donghyeon40@example.org | 직업: 기타 기능관련 종사원
# 이름: 이민수 | 이메일: minseogseo@example.org | 직업: 섀시 조립 및 설치원
# 이름: 이지영 | 이메일: fo@example.org | 직업: 철로 설치 및 보수원
# 이름: 손성수 | 이메일: jungsugim@example.org | 직업: 건설자재 시험원
# 이름: 김영철 | 이메일: aca@example.net | 직업: 치과기공사
# 이름: 민진호 | 이메일: jinho14@example.net | 직업: 예능 강사
# 이름: 김준서 | 이메일: jihye12@example.org | 직업: 영관급 이상
# 이름: 이채원 | 이메일: areum58@example.com | 직업: 기타 목재 및 종이 관련 기계조작원
# 이름: 이우진 | 이메일: isanghun@example.net | 직업: 섬유제조 기계조작원
# 이름: 황현숙 | 이메일: areum35@example.net | 직업: 주조기 조작원
# 이름: 윤정자 | 이메일: seoyunseo@example.com | 직업: 전기 및 전자 설비 조작원
# 이름: 김서준 | 이메일: hayungim@example.org | 직업: 기타 사육관련 종사원
# 이름: 지정식 | 이메일: fgu@example.org | 직업: 전기/전자 및 기계 공학 시험원
# 이름: 박서연 | 이메일: jyun@example.org | 직업: 조적공 및 석재 부설원
# 이름: 김영길 | 이메일: gweonhyeonju@example.com | 직업: 인사 및 노사 관련 전문가
# 이름: 서하은 | 이메일: junhoi@example.net | 직업: 목제품 제조관련 종사원
# 이름: 김우진 | 이메일: coeminjae@example.org | 직업: 항공기 객실승무원
# 이름: 이현정 | 이메일: mgim@example.net | 직업: 큐레이터 및 문화재 보존원
# 이름: 류순옥 | 이메일: ojang@example.net | 직업: 기타 전기/전자기기 설치 및 수리원
# 이름: 김은경 | 이메일: aseo@example.org | 직업: 총무 사무원
# 이름: 김선영 | 이메일: jangyeongho@example.net | 직업: 건축 석공
# 이름: 안광수 | 이메일: sangceol79@example.net | 직업: 일반 의사
# 이름: 서도윤 | 이메일: sangho97@example.net | 직업: 기타 서비스관련 단순 종사원
# 이름: 최경숙 | 이메일: ai@example.org | 직업: 자연과학 연구원
# 이름: 강유진 | 이메일: ghan@example.org | 직업: 과실 및 채소 관련 기계조작원
# 이름: 이영철 | 이메일: yjo@example.org | 직업: 식품 및 담배 등급원
# 이름: 김숙자 | 이메일: ijunseo@example.com | 직업: 마술사 및 기타 문화/ 예술 관련 종사자
# 이름: 김서윤 | 이메일: bageunju@example.org | 직업: 기타 금융 및 보험 관련 전문가
# 이름: 김혜진 | 이메일: juweon20@example.com | 직업: 기타 사육관련 종사원
# 이름: 우영미 | 이메일: jiyeon58@example.net | 직업: 기타 건축마감관련 기능 종사원
# 이름: 김민수 | 이메일: ihyejin@example.com | 직업: 재단사
# 이름: 문상현 | 이메일: gyeongsugbae@example.org | 직업: 기타 기능관련 종사원
# 이름: 이상현 | 이메일: ijiweon@example.org | 직업: 유치원 교사
# 이름: 김지우 | 이메일: minseogson@example.net | 직업: 환경 미화원 및 재활용품 수거원
# 이름: 김영일 | 이메일: wgim@example.net | 직업: 매장계산원 및 요금정산원
# 이름: 박승민 | 이메일: ijeongja@example.org | 직업: 육류/어패류 및 낙농품 가공 기계조작원
# 이름: 남시우 | 이메일: ojeongho@example.net | 직업: 영관급 이상
# 이름: 최상호 | 이메일: hyejin33@example.com | 직업: 주유원
# 이름: 강정수 | 이메일: vheo@example.com | 직업: 고객 상담 및 모니터 요원
# 이름: 한미숙 | 이메일: yeonghyi58@example.net | 직업: 영양사
# 이름: 이준영 | 이메일: yujingim@example.org | 직업: 건설 배관공
# 이름: 한성훈 | 이메일: caeweoni@example.org | 직업: 손해사정인
# 이름: 주서영 | 이메일: minjae42@example.net | 직업: 웹 및 멀티미디어 디자이너
# 이름: 김민재 | 이메일: hyeonsuggang@example.com | 직업: 건설 및 채굴 기계 운전원
# 이름: 오성수 | 이메일: junhogim@example.org | 직업: 국가/지방 및 공공행정 사무원
# 이름: 박미정 | 이메일: mi@example.org | 직업: 수금원
# 이름: 차준혁 | 이메일: jeongungi@example.net | 직업: 웹 및 멀티미디어 기획자
# 이름: 김도현 | 이메일: jbag@example.org | 직업: 기타 행정 및 경영지원 관리자
# 이름: 최지은 | 이메일: jojihun@example.org | 직업: 음식 배달원
# 이름: 이민서 | 이메일: ayun@example.net | 직업: 모피 및 가죽의복 제조원
# 이름: 홍정웅 | 이메일: jeongsig36@example.org | 직업: 시각 디자이너
# 이름: 고정남 | 이메일: si@example.org | 직업: 점토제품 생산기 조작원
# 이름: 이현숙 | 이메일: jeongjai@example.org | 직업: 종이제품 생산기 조작원
# 이름: 김은정 | 이메일: areum52@example.org | 직업: 섀시 조립 및 설치원
# 이름: 이영환 | 이메일: eyang@example.net | 직업: 지휘자/작곡가 및 연주가
# 이름: 김재현 | 이메일: sangho28@example.org | 직업: 구두 미화원
# 이름: 김지현 | 이메일: tju@example.com | 직업: 전기/가스 및 수도 관련 관리자
# 이름: 김은지 | 이메일: gyeonghyihwang@example.org | 직업: 응용 소프트웨어 개발자
# 이름: 오경숙 | 이메일: yeonghwanjeong@example.net | 직업: 판사 및 검사
# 이름: 박영호 | 이메일: yeongjingim@example.org | 직업: 제품 및 광고 영업원
# 이름: 이지현 | 이메일: bagjeongsu@example.net | 직업: 패턴사
# 이름: 최지영 | 이메일: anjeongja@example.net | 직업: 중/고등학교 교사
# 이름: 장서현 | 이메일: junhoi@example.com | 직업: 공업 배관공
# 이름: 김승민 | 이메일: yunseo86@example.net | 직업: 컴퓨터시스템 설계 및 분석가
# 이름: 장현지 | 이메일: yejini@example.com | 직업: 기타 식품가공관련 종사원
# 이름: 이종수 | 이메일: ijihun@example.net | 직업: 영양사
# 이름: 안은서 | 이메일: byeongceoljin@example.org | 직업: 기타 전문서비스 관리자
# 이름: 윤정호 | 이메일: hayun56@example.net | 직업: 사서 및 기록물관리사
# 이름: 류지현 | 이메일: nhwang@example.com | 직업: 악기제조 및 조율사
# 이름: 김현주 | 이메일: yangyejun@example.org | 직업: 조세행정 사무원
# 이름: 이정희 | 이메일: bmun@example.org | 직업: 기타 건설/전기 및 생산 관련 관리자
# 이름: 김정수 | 이메일: bagjimin@example.net | 직업: 모피 및 가죽의복 제조원
# 이름: 김예진 | 이메일: egim@example.com | 직업: 감사 사무원
# 이름: 김민수 | 이메일: scoe@example.org | 직업: 기타 배달원
# 이름: 이혜진 | 이메일: kcoe@example.com | 직업: 컴퓨터 강사
# 이름: 김영길 | 이메일: eunjeongi@example.net | 직업: 기타 판매 및 고객 서비스 관리자
# 이름: 이영일 | 이메일: baeyujin@example.com | 직업: 무역 사무원
# 이름: 구영숙 | 이메일: cgim@example.org | 직업: 스포츠 및 레크레이션 강사
# 이름: 이승현 | 이메일: simjiweon@example.net | 직업: 환경공학 시험원
# 이름: 오민재 | 이메일: yeonghwanmun@example.org | 직업: 가전제품 설치 및 수리원
# 이름: 박예은 | 이메일: seonghun29@example.com | 직업: 건설 및 광업 단순 종사원
# 이름: 문혜진 | 이메일: jihubaeg@example.org | 직업: 경기심판 및 경기기록원
# 이름: 최종수 | 이메일: ubag@example.org | 직업: 한복 제조원
# 이름: 이영숙 | 이메일: ujin58@example.net | 직업: 김치 및 밑반찬 제조 종사원
# 이름: 류은서 | 이메일: yeji49@example.net | 직업: 수금원
# 이름: 김지혜 | 이메일: gyeongsu84@example.org | 직업: 화학제품 생산기 조작원
# 이름: 김지연 | 이메일: minminjun@example.com | 직업: 총무 사무원
# 이름: 박진우 | 이메일: yejin13@example.org | 직업: 보험 설계사 및 간접투자증권 판매인
# 이름: 황영자 | 이메일: mi@example.com | 직업: 연예인 및 스포츠 매니저
# 이름: 강준혁 | 이메일: baejiu@example.org | 직업: 영상 및 관련 장비 설치 및 수리원
# 이름: 한현우 | 이메일: sangho23@example.org | 직업: 상점 판매원
# 이름: 강혜진 | 이메일: gimjunho@example.com | 직업: 금속가공관련 제어장치 조작원
# 이름: 강시우 | 이메일: jihu19@example.com | 직업: 바텐더
# 이름: 이경숙 | 이메일: kgim@example.org | 직업: 문화/예술/디자인 및 영상관련 관리자
# 이름: 김민지 | 이메일: yeongsugson@example.com | 직업: 일식 주방장 및 조리사
# 이름: 김영길 | 이메일: hyeonjeongyang@example.com | 직업: 숙박시설 서비스원
# 이름: 성영희 | 이메일: jhwang@example.net | 직업: 목재 가공관련 기계 조작원
# 이름: 박성민 | 이메일: fyun@example.org | 직업: 기계공학 기술자 및 연구원
# 이름: 구승현 | 이메일: jiu82@example.net | 직업: 기술 영업원
# 이름: 한상호 | 이메일: myeongsug46@example.org | 직업: 석유 및 천연가스제조 관련 제어장치 조작원
# 이름: 김미정 | 이메일: jeongseongjin@example.com | 직업: 가스/에너지 기술자 및 연구원
# 이름: 서영자 | 이메일: heoseongho@example.org | 직업: 곡물가공제품 기계 조작원
# 이름: 유진우 | 이메일: gjang@example.net | 직업: 보일러 설치 및 정비원
# 이름: 서영일 | 이메일: myeongsug78@example.net | 직업: 만화가 및 만화영화 작가
# 이름: 김영철 | 이메일: gimjia@example.com | 직업: 대학 교수
# 이름: 김영진 | 이메일: zbag@example.net | 직업: 기타 석유 및 화학물 가공장치 조작원
# 이름: 김승민 | 이메일: iseungmin@example.com | 직업: 기타 문리/기술 및 예능 강사
# 이름: 임영환 | 이메일: ugwag@example.com | 직업: 조명기사 및 영사기사
# 이름: 김영호 | 이메일: jiyeongson@example.org | 직업: 경리 사무원
# 이름: 박지현 | 이메일: handonghyeon@example.net | 직업: 양식 주방장 및 조리사
# 이름: 지우진 | 이메일: dohyeon34@example.org | 직업: 계기 검침원 및 가스점검원
# 이름: 김지영 | 이메일: bagjeongho@example.com | 직업: 주유원
# 이름: 김상현 | 이메일: jeongho32@example.net | 직업: 신용 추심원
# 이름: 김정웅 | 이메일: ugim@example.org | 직업: 생명과학 연구원
# 이름: 김은영 | 이메일: rbag@example.net | 직업: 원예작물 재배원
# 이름: 박현정 | 이메일: sumin18@example.com | 직업: 기타 전기/전자기기 설치 및 수리원
# 이름: 오정숙 | 이메일: jangsubin@example.org | 직업: 간판 제작 및 설치원
# 이름: 남현숙 | 이메일: jeongsungim@example.com | 직업: 건축 목공
# 이름: 박예원 | 이메일: eunjugim@example.org | 직업: 재봉사
# 이름: 남경숙 | 이메일: seonghun28@example.net | 직업: 결혼 상담원 및 웨딩플래너
# 이름: 이유진 | 이메일: mgang@example.com | 직업: 기타 행정 및 경영지원 관리자
# 이름: 김예진 | 이메일: yeonghwan29@example.org | 직업: 전기 및 전자 설비 조작원
# 이름: 박하윤 | 이메일: doyungim@example.org | 직업: 기타 미용관련 서비스 종사원
# 이름: 권영호 | 이메일: jinugim@example.com | 직업: 한의사
# 이름: 이동현 | 이메일: gimseoyeong@example.net | 직업: 기타 경호 및 보안 관련 종사원
# 이름: 김광수 | 이메일: cgim@example.net | 직업: 정보 시스템 운영자
# 이름: 최정남 | 이메일: ii@example.com | 직업: 채소 및 특용작물 재배원
# 이름: 배숙자 | 이메일: gimhyeonji@example.org | 직업: 조림/영림 및 벌목원
# 이름: 이현숙 | 이메일: ggim@example.net | 직업: 여행상품 개발자
# 이름: 김예은 | 이메일: kson@example.org | 직업: 기타 의복 제조원
# 이름: 최미영 | 이메일: jeongung48@example.net | 직업: 의회의원/고위공무원 및 공공단체임원
# 이름: 김순옥 | 이메일: zgim@example.net | 직업: 전산 자료 입력원 및 사무 보조원
# 이름: 송미숙 | 이메일: yejini@example.org | 직업: 타이어 및 고무제품 생산기 조작원
# 이름: 강현정 | 이메일: ojiweon@example.net | 직업: 세탁원 및 다림질원
# 이름: 하현지 | 이메일: isiu@example.com | 직업: 유리제조 및 가공기 조작원
# 이름: 구선영 | 이메일: yeongjai@example.net | 직업: 상품 대여원
# 이름: 윤숙자 | 이메일: gimjiyeon@example.com | 직업: 제분 및 도정 관련 기계 조작원
# 이름: 이지은 | 이메일: wi@example.net | 직업: 석유 및 천연가스제조 관련 제어장치 조작원
# 이름: 오혜진 | 이메일: myeongjagweon@example.org | 직업: 숙박/여행/오락 및 스포츠 관련 관리자
# 이름: 이미영 | 이메일: yunyunseo@example.com | 직업: 펄프 및 종이 제조장치 조작원
# 이름: 김서윤 | 이메일: yeongho55@example.org | 직업: 소방공학 기술자 및 연구원
# 이름: 김서영 | 이메일: gyeongsug70@example.com | 직업: 기타 판매 및 고객 서비스 관리자
# 이름: 박정숙 | 이메일: wgo@example.net | 직업: 정보 시스템 운영자
# 이름: 최영환 | 이메일: qgim@example.org | 직업: 도금 및 금속분무기 조작원
# 이름: 김순옥 | 이메일: jinho29@example.com | 직업: 시스템 소프트웨어 개발자
# 이름: 안민재 | 이메일: dan@example.com | 직업: 상담 전문가 및 청소년 지도사
# 이름: 강상현 | 이메일: bjang@example.net | 직업: 인사 및 노사 관련 전문가
# 이름: 안준영 | 이메일: jeongsugjeong@example.com | 직업: 가사 도우미
# 이름: 김명자 | 이메일: seoyeongcoe@example.com | 직업: 회계사
# 이름: 김영미 | 이메일: seungmin48@example.net | 직업: 자동조립라인 및 산업용 로봇 조작원
# 이름: 배성현 | 이메일: jiyeongson@example.net | 직업: 콘크리트공
# 이름: 권정웅 | 이메일: yeonghwangim@example.com | 직업: 인문과학 연구원
# 이름: 박민재 | 이메일: gimseonyeong@example.org | 직업: 시민 단체 활동가
# 이름: 박정자 | 이메일: fcoe@example.com | 직업: 냉/난방 관련 설비 조작원
# 이름: 김혜진 | 이메일: gimgwangsu@example.net | 직업: 낙농업관련 종사원
# 이름: 김영환 | 이메일: gimjeongung@example.org | 직업: 정육원 및 도축원
# 이름: 배상훈 | 이메일: sugja41@example.com | 직업: 약사 및 한약사
# 이름: 홍영식 | 이메일: mi@example.com | 직업: 금속 / 재료공학 시험원
# 이름: 서동현 | 이메일: vgim@example.org | 직업: 택시 운전원
# 이름: 박민준 | 이메일: juweon42@example.net | 직업: 재활용 처리 및 소각로 조작원
# 이름: 고민서 | 이메일: jiyeong18@example.com | 직업: 의회의원/고위공무원 및 공공단체임원
# 이름: 조진호 | 이메일: kjo@example.org | 직업: 경량 철골공
# 이름: 김병철 | 이메일: jiu69@example.com | 직업: 기술 영업원
# 이름: 장도윤 | 이메일: jiweonseo@example.com | 직업: 인문과학 연구원
# 이름: 조영호 | 이메일: san@example.org | 직업: 재단사
# 이름: 김상호 | 이메일: ehwang@example.org | 직업: 기타 배관공
# 이름: 문예준 | 이메일: dbag@example.net | 직업: 전문 의사
# 이름: 김건우 | 이메일: dgim@example.com | 직업: 주조원
# 이름: 이성현 | 이메일: munmyeongsug@example.org | 직업: 감독 및 기술감독
# 이름: 김준서 | 이메일: ygim@example.com | 직업: 사회과학 연구원
# 이름: 최상철 | 이메일: ogjacoe@example.org | 직업: 판사 및 검사
# 이름: 김정자 | 이메일: idoyun@example.net | 직업: 작가 및 관련 전문가
# 이름: 송지훈 | 이메일: yejuni@example.com | 직업: 보험 및 금융 관리자
# 이름: 박영희 | 이메일: eungyeong09@example.com | 직업: 가스/에너지 기술자 및 연구원
# 이름: 박숙자 | 이메일: cunja85@example.org | 직업: 섀시 조립 및 설치원
# 이름: 이정숙 | 이메일: hanyujin@example.com | 직업: 운송관련 관리자
# 이름: 최미영 | 이메일: dgim@example.net | 직업: 보육 교사
# 이름: 구하윤 | 이메일: gimhyeonji@example.net | 직업: 세탁관련 기계조작원
# 이름: 김경희 | 이메일: yungyeongsug@example.net | 직업: 토목공학 기술자
# 이름: 박유진 | 이메일: xgang@example.net | 직업: 화물차 및 특수차 운전원
# 이름: 황현주 | 이메일: gimminsu@example.org | 직업: 무인 경비원
# 이름: 성도현 | 이메일: areum89@example.com | 직업: 회계사
# 이름: 권정웅 | 이메일: jiyeon09@example.net | 직업: 아나운서 및 리포터
# 이름: 최정웅 | 이메일: jungsui@example.com | 직업: 육류/어패류 및 낙농품 가공 기계조작원
# 이름: 박수빈 | 이메일: gyeongsuggwag@example.org | 직업: 전기/전자 및 기계 공학 시험원
# 이름: 김하은 | 이메일: jiyeon73@example.net | 직업: 변리사
# 이름: 강준서 | 이메일: hyeonji59@example.net | 직업: 전자 부품 및 제품 제조 기계조작원
# 이름: 안영자 | 이메일: sryu@example.org | 직업: 지휘자/작곡가 및 연주가
# 이름: 박성훈 | 이메일: seohyeon80@example.net | 직업: 환경공학 시험원
# 이름: 서은주 | 이메일: hyejinbag@example.net | 직업: 미장공
# 이름: 김영식 | 이메일: ojinu@example.org | 직업: 예능 강사
# 이름: 하성훈 | 이메일: gimjimin@example.net | 직업: 매장계산원 및 요금정산원
# 이름: 배지훈 | 이메일: misug86@example.org | 직업: 패턴사
# 이름: 최종수 | 이메일: minjunnam@example.com | 직업: 떡제조원
# 이름: 김재현 | 이메일: ai@example.org | 직업: 전기/가스 및 수도 관련 관리자
# 이름: 조준혁 | 이메일: rgim@example.com | 직업: 선장/항해사 및 도선사
# 이름: 이경희 | 이메일: yunseo04@example.net | 직업: 기타 스포츠 및 레크레이션 관련 전문가
# 이름: 임정수 | 이메일: jeonghyigim@example.net | 직업: 기타 채굴 및 토목 관련 종사자
# 이름: 박준서 | 이메일: hyeonu23@example.net | 직업: 패션 디자이너
# 이름: 김서준 | 이메일: nryu@example.net | 직업: 경기감독 및 코치
# 이름: 정정웅 | 이메일: mijeong25@example.com | 직업: 법무사 및 집행관
# 이름: 이예원 | 이메일: byeongceolgang@example.org | 직업: 보일러 설치 및 정비원
# 이름: 김지후 | 이메일: isunja@example.net | 직업: 손해사정인
# 이름: 강승민 | 이메일: seungmin87@example.net | 직업: 화물열차 차장 및 관련 종사원
# 이름: 박아름 | 이메일: gimjiyeon@example.com | 직업: 기타 경호 및 보안 관련 종사원
# 이름: 이영희 | 이메일: iseoyeon@example.org | 직업: 출판물 전문가
# 이름: 남유진 | 이메일: li@example.org | 직업: 사서 및 기록물관리사
# 이름: 이지연 | 이메일: gyeongsugo@example.net | 직업: 기타 이미용/예식 및 의료보조 서비스 종사원
# 이름: 오상현 | 이메일: gimyeonggil@example.org | 직업: 결혼 상담원 및 웨딩플래너
# 이름: 송현숙 | 이메일: seongmin15@example.net | 직업: 택배원
# 이름: 우상훈 | 이메일: migyeong47@example.net | 직업: 유치원 교사
# 이름: 김현지 | 이메일: di@example.net | 직업: 운송 사무원
# 이름: 한서현 | 이메일: gimhyejin@example.org | 직업: 기타 이미용/예식 및 의료보조 서비스 종사원
# 이름: 손영미 | 이메일: iyunseo@example.org | 직업: 제조관련 단순 종사원
# 이름: 윤성호 | 이메일: jinyeongil@example.org | 직업: 매표원 및 복권 판매원
# 이름: 송건우 | 이메일: jeonghobag@example.net | 직업: 기타 제조관련 기계 조작원
# 이름: 윤상호 | 이메일: seohyeon24@example.org | 직업: 생명과학 시험원
# 이름: 안예은 | 이메일: gimyejun@example.com | 직업: 내선전공
# 이름: 안경자 | 이메일: yeongmi27@example.net | 직업: 기타 석유 및 화학물 가공장치 조작원
# 이름: 송승민 | 이메일: gimyujin@example.com | 직업: 인쇄기 조작원
# 이름: 박영길 | 이메일: gweonyeongho@example.net | 직업: 판금기 조작원
# 이름: 김경희 | 이메일: imisug@example.org | 직업: 무인 경비원
# 이름: 송지원 | 이메일: yeonghobag@example.org | 직업: 기타 문리/기술 및 예능 강사
# 이름: 백윤서 | 이메일: nyun@example.net | 직업: 치과위생사
# 이름: 김경숙 | 이메일: yeongsubae@example.net | 직업: 상품중개인 및 경매사
# 이름: 장은서 | 이메일: iareum@example.org | 직업: 중/고등학교 교사
# 이름: 김명자 | 이메일: seojun45@example.com | 직업: 만화가 및 만화영화 작가
# 이름: 최주원 | 이메일: seojun74@example.net | 직업: 섬유제조 기계조작원
# 이름: 차건우 | 이메일: jihyeonbag@example.net | 직업: 금속 / 재료공학 연구원 및 기술자
# 이름: 백미영 | 이메일: seongjinsin@example.org | 직업: 안마사
# 이름: 오은서 | 이메일: seongsui@example.com | 직업: 기타 직물 및 신발 관련 기계조작원 및 조립원
# 이름: 김현숙 | 이메일: qgwag@example.org | 직업: 기타 기술영업 및 중개 관련 종사자
# 이름: 박미경 | 이메일: ajang@example.net | 직업: 약사 및 한약사
# 이름: 박순자 | 이메일: tmun@example.org | 직업: 경기심판 및 경기기록원
# 이름: 오서영 | 이메일: seohyeon61@example.com | 직업: 법률/경찰/소방 및 교도 관리자
# 이름: 김영철 | 이메일: mgim@example.com | 직업: 가사 도우미
# 이름: 이은서 | 이메일: bagcunja@example.com | 직업: 대학 교육조교
# 이름: 이영호 | 이메일: yeonghwanyang@example.org | 직업: 기술 및 기능계 강사
# 이름: 김영환 | 이메일: yeonghyicoe@example.com | 직업: 기타 종교관련 종사자
# 이름: 김정자 | 이메일: qjeong@example.com | 직업: 기타 스포츠 및 레크레이션 관련 전문가
# 이름: 김정자 | 이메일: nbag@example.net | 직업: 도배공 및 유리 부착원
# 이름: 오상호 | 이메일: ogim@example.org | 직업: 기타 건설/전기 및 생산 관련 관리자
# 이름: 김정자 | 이메일: soneunji@example.com | 직업: 섬유공학 기술자 및 연구원
# 이름: 이은영 | 이메일: xhong@example.com | 직업: 섬유공학 기술자 및 연구원
# 이름: 이옥자 | 이메일: gyeongsugmin@example.com | 직업: 소방관
# 이름: 고성훈 | 이메일: seungminbag@example.org | 직업: 제분 및 도정 관련 기계 조작원
# 이름: 김민준 | 이메일: minseo32@example.org | 직업: 운송장비 조립원
# 이름: 김도현 | 이메일: baghaeun@example.net | 직업: 식품 및 담배 등급원
# 이름: 오재호 | 이메일: jihyeoncoe@example.com | 직업: 제빵원 및 제과원
# 이름: 박현숙 | 이메일: useungmin@example.net | 직업: 메이크업 아티스트 및 분장사
# 이름: 우예지 | 이메일: myeongjacoe@example.org | 직업: 간호사
# 이름: 홍상철 | 이메일: eunyeong86@example.net | 직업: 기타 비금속제품관련 생산기 조작원
# 이름: 김채원 | 이메일: ieunji@example.com | 직업: 응급구조사
# 이름: 장은지 | 이메일: fcoe@example.org | 직업: 기타 금융 및 보험 관련 전문가
# 이름: 홍서준 | 이메일: jaeho27@example.net | 직업: 출판물 전문가
# 이름: 최서현 | 이메일: gyeonghyibag@example.com | 직업: 음식 배달원
# 이름: 한재호 | 이메일: fbag@example.net | 직업: 금속가공관련 제어장치 조작원
# 이름: 노영철 | 이메일: coesangho@example.org | 직업: 전자공학 기술자 및 연구원
# 이름: 박은주 | 이메일: myeongsug19@example.net | 직업: 번역가
# 이름: 이정훈 | 이메일: vbag@example.com | 직업: 문리 및 어학 강사
# 이름: 김수진 | 이메일: bson@example.net | 직업: 웨이터
# 이름: 윤수빈 | 이메일: dgim@example.net | 직업: 판사 및 검사
# 이름: 백현지 | 이메일: gimyeongceol@example.com | 직업: 김치 및 밑반찬 제조 종사원
# 이름: 김현지 | 이메일: guyeongho@example.org | 직업: 식품 및 담배 등급원
# 이름: 이성수 | 이메일: mijeongheo@example.org | 직업: 증권 및 외환 딜러
# 이름: 송승현 | 이메일: pi@example.org | 직업: 섬유제조 기계조작원
# 이름: 김준호 | 이메일: seongminbag@example.com | 직업: 특수교육 교사
# 이름: 김서윤 | 이메일: yeongsuni@example.com | 직업: 기타 스포츠 및 레크레이션 관련 전문가
# 이름: 김영희 | 이메일: jihyeongang@example.com | 직업: 구두 미화원
# 이름: 안순자 | 이메일: seojeonghyi@example.org | 직업: 상담 전문가 및 청소년 지도사
# 이름: 구영순 | 이메일: aryu@example.org | 직업: 바닥재 시공원
# 이름: 이민석 | 이메일: seungmin21@example.com | 직업: 장학관/연구관 및 교육 관련 전문가
# 이름: 서예준 | 이메일: hsong@example.net | 직업: 행사기획자
# 이름: 김성민 | 이메일: iseohyeon@example.org | 직업: 기타 기능관련 종사원
# 이름: 곽선영 | 이메일: sumin81@example.net | 직업: 영상/녹화 및 편집 기사
# 이름: 이준영 | 이메일: seonghocoe@example.net | 직업: 판금원
# 이름: 홍시우 | 이메일: eunji21@example.net | 직업: 도금 및 금속분무기 조작원
# 이름: 손준영 | 이메일: yeongsu47@example.net | 직업: 실내장식 디자이너
# 이름: 권윤서 | 이메일: pgim@example.net | 직업: 소방공학 기술자 및 연구원
# 이름: 하민서 | 이메일: eno@example.com | 직업: 건축 도장공
# 이름: 김도윤 | 이메일: seoyuni@example.net | 직업: 통신 및 방송송출 장비 기사
# 이름: 박승현 | 이메일: eunyeonghong@example.com | 직업: 패스트푸드원
# 이름: 하병철 | 이메일: sujingim@example.com | 직업: 생산 및 품질 관리 사무원
# 이름: 김상현 | 이메일: rgim@example.org | 직업: 통신서비스판매원
# 이름: 이성민 | 이메일: vbag@example.com | 직업: 농업용 및 기타 기계장비 설치 및 정비원
# 이름: 김준혁 | 이메일: sju@example.net | 직업: 감독 및 기술감독
# 이름: 임은지 | 이메일: jimin06@example.net | 직업: 제관기 조작원
# 이름: 이아름 | 이메일: gcoe@example.com | 직업: 가수 및 성악가
# 이름: 주서윤 | 이메일: haboram@example.org | 직업: 금속가공 기계조작원
# 이름: 홍영철 | 이메일: junyeong17@example.net | 직업: 음향 및 녹음 기사
# 이름: 김은지 | 이메일: nryu@example.com | 직업: 사회복지관련 관리자
# 이름: 김도현 | 이메일: myeongsug46@example.net | 직업: 양장 및 양복 제조원
# 이름: 김현지 | 이메일: minjaecoe@example.com | 직업: 섬유제조 기계조작원
# 이름: 류종수 | 이메일: zi@example.org | 직업: 기타 석유 및 화학물 가공장치 조작원
# 이름: 박순자 | 이메일: jimingang@example.com | 직업: 수의사
# 이름: 김영일 | 이메일: gimhyejin@example.org | 직업: 토목공학 기술자
# 이름: 이종수 | 이메일: yunhyeonu@example.net | 직업: 컴퓨터 하드웨어 기술자 및 연구원
# 이름: 이경수 | 이메일: gimjongsu@example.org | 직업: 주유원
# 이름: 차수진 | 이메일: juseongsu@example.com | 직업: 전기/전자 및 기계 공학 시험원
# 이름: 이지아 | 이메일: mijeong89@example.com | 직업: 비서
# 이름: 이하은 | 이메일: eunseobag@example.com | 직업: 홍보 도우미 및 판촉원
# 이름: 주선영 | 이메일: juweon79@example.com | 직업: 대학 교수
# 이름: 윤서현 | 이메일: yeeun66@example.net | 직업: 사회복지관련 관리자
# 이름: 김동현 | 이메일: hyeonjisong@example.net | 직업: 배우 및 모델
# 이름: 김서영 | 이메일: mo@example.net | 직업: 기타 판매 및 고객 서비스 관리자
# 이름: 문영환 | 이메일: sanghogim@example.org | 직업: 곡식작물 재배원
# 이름: 박도윤 | 이메일: gyeongsug89@example.org | 직업: 사진인화 및 현상기 조작원
# 이름: 이준혁 | 이메일: ibyeongceol@example.com | 직업: 산업전공
# 이름: 이현우 | 이메일: yeongsuna@example.com | 직업: 선박 갑판승무원 및 관련 종사원
# 이름: 손민준 | 이메일: hayun84@example.org | 직업: 금속기계부품 조립원
# 이름: 이정남 | 이메일: vhan@example.com | 직업: 기술 및 기능계 강사
# 이름: 류현준 | 이메일: haeunjo@example.net | 직업: 선박 및 열차 객실승무원
# 이름: 서채원 | 이메일: anogsun@example.net | 직업: 조경원
# 이름: 박지민 | 이메일: ogsungim@example.org | 직업: 생산 및 품질 관리 사무원
# 이름: 신미정 | 이메일: zryu@example.org | 직업: 건설 및 광업 단순 종사원
# 이름: 김민준 | 이메일: uhan@example.org | 직업: 양장 및 양복 제조원
# 이름: 하채원 | 이메일: mjin@example.net | 직업: 건설자재 시험원
# 이름: 주예진 | 이메일: yeongja15@example.com | 직업: 주차 관리원 및 안내원
# 이름: 이옥자 | 이메일: hyeonjunbag@example.com | 직업: 금속공작기계 조작원
# 이름: 홍정웅 | 이메일: minjun08@example.org | 직업: 수금원
# 이름: 홍영환 | 이메일: mbag@example.org | 직업: 냉/난방 관련 설비 조작원
# 이름: 김성훈 | 이메일: minjungim@example.org | 직업: 시민 단체 활동가
# 이름: 우정호 | 이메일: kseo@example.org | 직업: 내선전공
# 이름: 이재호 | 이메일: gbae@example.org | 직업: 출판물 전문가
# 이름: 박예은 | 이메일: yeongho45@example.com | 직업: 조경 기술자
# 이름: 김상철 | 이메일: yeongsuni@example.com | 직업: 중/고등학교 교사
# 이름: 서예준 | 이메일: hyejinbag@example.org | 직업: 음향 및 녹음 기사
# 이름: 윤경숙 | 이메일: ogja55@example.net | 직업: 기타 음식서비스 종사원
# 이름: 송시우 | 이메일: sonogsun@example.net | 직업: 기타 금융 및 보험 관련 전문가
# 이름: 노시우 | 이메일: bagyeweon@example.com | 직업: 콘크리트공
# 이름: 이예준 | 이메일: jungsugweon@example.net | 직업: 도배공 및 유리 부착원
# 이름: 이지영 | 이메일: jieunbae@example.com | 직업: 냉동/냉장 /공조기 설치 및 정비원
# 이름: 윤정자 | 이메일: eunyeong87@example.net | 직업: 한식 주방장 및 조리사
# 이름: 이종수 | 이메일: baggeonu@example.com | 직업: 중식 주방장 및 조리사
# 이름: 백건우 | 이메일: munjunhyeog@example.com | 직업: 위생사
# 이름: 김보람 | 이메일: sangho86@example.com | 직업: 영관급 이상
# 이름: 권성훈 | 이메일: misugo@example.com | 직업: 가수 및 성악가
# 이름: 이지은 | 이메일: zyun@example.com | 직업: 제화원
# 이름: 최미경 | 이메일: fbag@example.com | 직업: 용접기 조작원
# 이름: 오경자 | 이메일: bagyeongsug@example.com | 직업: 귀금속 및 보석 세공원
# 이름: 박성훈 | 이메일: wsong@example.net | 직업: 경기감독 및 코치
# 이름: 우성민 | 이메일: baejeongho@example.org | 직업: 치과기공사
# 이름: 하영희 | 이메일: ryusangho@example.org | 직업: 전문 의사
# 이름: 김정수 | 이메일: eunyeong73@example.com | 직업: 토목공학 기술자
# 이름: 김민서 | 이메일: eunjigim@example.org | 직업: 광석 및 석제품 가공기 조작원
# 이름: 박성수 | 이메일: jeongungjin@example.org | 직업: 기타 판매 및 고객 서비스 관리자
# 이름: 홍재호 | 이메일: gyeonghyigim@example.com | 직업: 도시 및 교통설계 전문가
# 이름: 최중수 | 이메일: hmin@example.net | 직업: 기타 사회복지관련 종사원
# 이름: 김광수 | 이메일: jiweon08@example.com | 직업: 기타 연극/영화 및 영상 관련 종사자
# 이름: 김명숙 | 이메일: fmun@example.net | 직업: 교육 관리자
# 이름: 오예준 | 이메일: jiminbag@example.net | 직업: 세탁관련 기계조작원
# 이름: 황영수 | 이메일: yeongsig27@example.org | 직업: 청원 경찰
# 이름: 황혜진 | 이메일: igeonu@example.net | 직업: 조사 전문가
# 이름: 김옥순 | 이메일: yeongjin99@example.org | 직업: 주차 관리원 및 안내원
# 이름: 이정웅 | 이메일: fnam@example.org | 직업: 화물차 및 특수차 운전원
# 이름: 이영환 | 이메일: minseo73@example.net | 직업: 아나운서 및 리포터
# 이름: 김성호 | 이메일: sangho23@example.com | 직업: 보일러 설치 및 정비원
# 이름: 민진우 | 이메일: agim@example.net | 직업: 상품중개인 및 경매사
# 이름: 박지후 | 이메일: yeongilcoe@example.com | 직업: 환경공학 기술자 및 연구원
# 이름: 이보람 | 이메일: wim@example.net | 직업: 점토제품 생산기 조작원
# 이름: 류지은 | 이메일: eunjuo@example.org | 직업: 건설 및 광업기계 설치 및 정비원
# 이름: 김중수 | 이메일: gimseongmin@example.com | 직업: 정부행정 관리자
# 이름: 박지현 | 이메일: myeongsuggim@example.net | 직업: 기타 건설관련 기능 종사원
# 이름: 김지원 | 이메일: junyeong65@example.org | 직업: 화물열차 차장 및 관련 종사원
# 이름: 곽수민 | 이메일: jeongsungim@example.com | 직업: 점토제품 생산기 조작원
# 이름: 박순자 | 이메일: gimsumin@example.net | 직업: 철도 기관차 및 전동차 정비원
# 이름: 이성민 | 이메일: ibae@example.net | 직업: 가수 및 성악가
# 이름: 김지아 | 이메일: jeongsiggim@example.net | 직업: 기획 및 마케팅 사무원
# 이름: 최아름 | 이메일: sunogbag@example.com | 직업: 세탁원 및 다림질원
# 이름: 정예은 | 이메일: jeongsun14@example.net | 직업: 감독 및 기술감독
# 이름: 황중수 | 이메일: yejigim@example.net | 직업: 항공기 객실승무원
# 이름: 고정웅 | 이메일: joboram@example.net | 직업: 금속가공 기계조작원
# 이름: 강수민 | 이메일: jeongsu52@example.com | 직업: 중식 주방장 및 조리사
# 이름: 강현숙 | 이메일: anminji@example.com | 직업: 섀시 조립 및 설치원
# 이름: 김명숙 | 이메일: jinugweon@example.org | 직업: 상품중개인 및 경매사
# 이름: 박예지 | 이메일: jihyeongim@example.net | 직업: 경찰관
# 이름: 조민지 | 이메일: hyeonjian@example.net | 직업: 손해사정인
# 이름: 이지아 | 이메일: seungminhong@example.net | 직업: 정육원 및 도축원
# 이름: 심예준 | 이메일: seoyeonmun@example.net | 직업: 경찰관
# 이름: 김숙자 | 이메일: jeongsigbag@example.com | 직업: 시각 디자이너
# 이름: 김종수 | 이메일: ogyeongja@example.org | 직업: 컴퓨터 보안 전문가
# 이름: 한수빈 | 이메일: minsugim@example.com | 직업: 변호사
# 이름: 김미숙 | 이메일: mijeongryu@example.net | 직업: 단조기 조작원
# 이름: 김지후 | 이메일: gimdoyun@example.org | 직업: 방문 판매원
# 이름: 이민석 | 이메일: hyeonju54@example.com | 직업: 이용사
# 이름: 서상훈 | 이메일: gimhyeonjun@example.com | 직업: 정육원 및 도축원
# 이름: 김우진 | 이메일: gangmyeongja@example.com | 직업: 간병인
# 이름: 정승민 | 이메일: bbag@example.org | 직업: 건축 도장공
# 이름: 박현지 | 이메일: eunjucoe@example.net | 직업: 큐레이터 및 문화재 보존원
# 이름: 윤지민 | 이메일: jungsuyu@example.org | 직업: 기타 운송장비 정비원
# 이름: 김옥순 | 이메일: igim@example.com | 직업: 장례 상담원 및 장례 지도사
# 이름: 이영미 | 이메일: jungsu47@example.org | 직업: 승강기 설치 및 정비원
# 이름: 김미정 | 이메일: mi@example.net | 직업: 실내장식 디자이너
# 이름: 문도윤 | 이메일: gimyeweon@example.net | 직업: 전자 부품 및 제품 제조 기계조작원
# 이름: 이은영 | 이메일: haeungim@example.org | 직업: 광원/채석원 및 석재 절단원
# 이름: 김현우 | 이메일: yeongsig49@example.org | 직업: 치과위생사
# 이름: 우승현 | 이메일: hyeonjunsong@example.com | 직업: 정보 시스템 운영자
# 이름: 차하윤 | 이메일: rhan@example.com | 직업: 직업상담사 및 취업 알선원
# 이름: 문명자 | 이메일: di@example.org | 직업: 중/고등학교 교사
# 이름: 김예준 | 이메일: seonyeong29@example.net | 직업: 우편물 집배원
# 이름: 곽성현 | 이메일: vi@example.com | 직업: 감사 사무원
# 이름: 오예원 | 이메일: gyeongsu54@example.org | 직업: 예능 강사
# 이름: 박영진 | 이메일: doyuncoe@example.net | 직업: 특수교육 교사
# 이름: 김영일 | 이메일: jia89@example.org | 직업: 법무사 및 집행관
# 이름: 김준서 | 이메일: eunjeonghong@example.org | 직업: 조경원
# 이름: 김미경 | 이메일: yi@example.com | 직업: 패션 디자이너
# 이름: 이종수 | 이메일: janggyeongsu@example.net | 직업: 기타 건축마감관련 기능 종사원
# 이름: 임은주 | 이메일: yeonghobag@example.net | 직업: 자동차 정비원
# 이름: 김정수 | 이메일: simyeongsig@example.net | 직업: 용접원
# 이름: 김영수 | 이메일: jgim@example.net | 직업: 기타 연극/영화 및 영상 관련 종사자
# 이름: 지지영 | 이메일: jiweon16@example.com | 직업: 사진인화 및 현상기 조작원
# 이름: 최정호 | 이메일: jongsubag@example.net | 직업: 식품/섬유 공학 및 에너지 시험원
# 이름: 김동현 | 이메일: gimjihyeon@example.net | 직업: 매표원 및 복권 판매원
# 이름: 이현정 | 이메일: gan@example.org | 직업: 방문 판매원
# 이름: 김도현 | 이메일: jihye32@example.org | 직업: 기타 직물 및 신발 관련 기계조작원 및 조립원
# 이름: 양동현 | 이메일: ijieun@example.com | 직업: 외선전공
# 이름: 이수민 | 이메일: minseonam@example.org | 직업: 일반기계 조립원
# 이름: 임주원 | 이메일: baghyeonu@example.net | 직업: 응용 소프트웨어 개발자
# 이름: 최미영 | 이메일: misug87@example.org | 직업: 도배공 및 유리 부착원
# 이름: 고미숙 | 이메일: jiyeon21@example.net | 직업: 기타 문리/기술 및 예능 강사
# 이름: 전민수 | 이메일: ojeongnam@example.com | 직업: 청원 경찰
# 이름: 김현우 | 이메일: odohyeon@example.com | 직업: 대학 교수
# 이름: 김유진 | 이메일: gimgyeongsug@example.com | 직업: 기타 비금속제품관련 생산기 조작원
# 이름: 이순옥 | 이메일: zo@example.net | 직업: 고객 상담 및 모니터 요원
# 이름: 김진호 | 이메일: bagseungmin@example.org | 직업: 기타 전문서비스 관리자
# 이름: 박서영 | 이메일: jeonghuni@example.net | 직업: 과수작물 재배원
# 이름: 고정숙 | 이메일: seongjingim@example.net | 직업: 정육원 및 도축원
# 이름: 김진호 | 이메일: heosumin@example.com | 직업: 식품 및 담배 등급원
# 이름: 최정웅 | 이메일: hsong@example.net | 직업: 정육원 및 도축원
# 이름: 이영철 | 이메일: miyeong36@example.net | 직업: 숙박시설 서비스원
# 이름: 최수진 | 이메일: gimjeongsun@example.org | 직업: 방사선사
# 이름: 김지원 | 이메일: ybag@example.org | 직업: 금속가공관련 제어장치 조작원
# 이름: 김정남 | 이메일: ujinjeon@example.net | 직업: 메이크업 아티스트 및 분장사
# 이름: 장지혜 | 이메일: lbag@example.com | 직업: 상품중개인 및 경매사
# 이름: 송성현 | 이메일: eyun@example.com | 직업: 피부미용 및 체형관리사
# 이름: 이민재 | 이메일: caeweoncoe@example.net | 직업: 전문 의사
# 이름: 이영희 | 이메일: wmun@example.org | 직업: 보험 및 금융 상품 개발자
# 이름: 전민지 | 이메일: kgim@example.org | 직업: 회계 사무원
# 이름: 강상훈 | 이메일: miyeongbag@example.org | 직업: 화학공학 시험원
# 이름: 이현정 | 이메일: idohyeon@example.com | 직업: 위관급
# 이름: 최영환 | 이메일: hyeonjigim@example.net | 직업: 화학제품 생산기 조작원
# 이름: 김은주 | 이메일: jiyeong57@example.org | 직업: 제화원
# 이름: 김지훈 | 이메일: seonghyeon71@example.net | 직업: 기타 종교관련 종사자
# 이름: 김서윤 | 이메일: gimjihyeon@example.net | 직업: 곡식작물 재배원
# 이름: 이지원 | 이메일: yejini@example.org | 직업: 연구 관리자
# 이름: 이광수 | 이메일: coeyunseo@example.com | 직업: 산업안전 및 위험 관리원
# 이름: 이영철 | 이메일: jieuncoe@example.com | 직업: 사회복지사
# 이름: 김도윤 | 이메일: gimjuweon@example.com | 직업: 판금기 조작원
# 이름: 류준영 | 이메일: fbag@example.com | 직업: 사진인화 및 현상기 조작원
# 이름: 이정순 | 이메일: seongjin80@example.com | 직업: 기자 및 논설위원
# 이름: 성준호 | 이메일: junhyeogjeong@example.com | 직업: 단조원
# 이름: 조준호 | 이메일: scoe@example.org | 직업: 섬유제조 기계조작원
# 이름: 김지은 | 이메일: jangjieun@example.com | 직업: 텔레마케터
# 이름: 한성훈 | 이메일: jomiyeong@example.org | 직업: 조림/영림 및 벌목원
# 이름: 송중수 | 이메일: dgim@example.com | 직업: 장기 부사관 및 준위
# 이름: 장은정 | 이메일: jeongmijeong@example.com | 직업: 웹 및 멀티미디어 기획자
# 이름: 김미숙 | 이메일: jiyeon44@example.com | 직업: 매표원 및 복권 판매원
# 이름: 황영철 | 이메일: isanghyeon@example.net | 직업: 건축 목공
# 이름: 차경수 | 이메일: myeongsug01@example.net | 직업: 매장계산원 및 요금정산원
# 이름: 윤유진 | 이메일: jiu46@example.com | 직업: 노점 및 이동 판매원
# 이름: 최지혜 | 이메일: gheo@example.org | 직업: 한식 주방장 및 조리사
# 이름: 이영수 | 이메일: vgim@example.net | 직업: 정부 및 공공 행정 전문가
# 이름: 이준혁 | 이메일: yheo@example.net | 직업: 음식 배달원
# 이름: 김정식 | 이메일: bagdonghyeon@example.net | 직업: 생명과학 시험원
# 이름: 강영환 | 이메일: yeongsug18@example.net | 직업: 고객 상담 및 모니터 요원
# 이름: 이은경 | 이메일: gangseojun@example.com | 직업: 주방 보조원
# 이름: 전예준 | 이메일: hyeonjeongi@example.org | 직업: 보건의료관련 관리자
# 이름: 한현지 | 이메일: misug10@example.com | 직업: 기타 제조관련 기계 조작원
# 이름: 김예은 | 이메일: yunseo39@example.org | 직업: 물품이동 장비 조작원
# 이름: 김현우 | 이메일: sanghun18@example.com | 직업: 사회복지사
# 이름: 박영희 | 이메일: gwangsu98@example.net | 직업: 건축 목공
# 이름: 이옥순 | 이메일: gyeonghyi91@example.net | 직업: 광석 및 석제품 가공기 조작원
# 이름: 장정숙 | 이메일: gcoe@example.net | 직업: 항공기 정비원
# 이름: 오수빈 | 이메일: zgim@example.net | 직업: 관세사
# 이름: 안민재 | 이메일: kgo@example.com | 직업: 번역가
# 이름: 윤예지 | 이메일: areum95@example.org | 직업: 회계 사무원
# 이름: 김성현 | 이메일: andonghyeon@example.com | 직업: 건축 도장공
# 이름: 강준호 | 이메일: ucoe@example.com | 직업: 기타 배관공
# 이름: 최경희 | 이메일: sugja32@example.org | 직업: 시민 단체 활동가
# 이름: 황민석 | 이메일: gimcunja@example.net | 직업: 자동차 부분품 조립원
# 이름: 김미숙 | 이메일: dohyeon49@example.com | 직업: 가전제품 설치 및 수리원
# 이름: 김중수 | 이메일: rbag@example.net | 직업: 건설 및 광업 단순 종사원
# 이름: 김서연 | 이메일: seongminjang@example.net | 직업: 가사 도우미
# 이름: 박은영 | 이메일: miyeong09@example.org | 직업: 컴퓨터 강사
# 이름: 고건우 | 이메일: bagcunja@example.net | 직업: 한식 주방장 및 조리사
# 이름: 남상호 | 이메일: yeongil48@example.org | 직업: 감정평가 전문가
# 이름: 송동현 | 이메일: eunseoi@example.com | 직업: 곡식작물 재배원
# 이름: 김영식 | 이메일: jia35@example.net | 직업: 제품 디자이너
# 이름: 양준혁 | 이메일: iminseog@example.org | 직업: 기타 건설/전기 및 생산 관련 관리자
# 이름: 백서윤 | 이메일: idonghyeon@example.com | 직업: 기타 자동차 운전원
# 이름: 권준서 | 이메일: seonyeong11@example.org | 직업: 경영지원 관리자
# 이름: 하혜진 | 이메일: jihyeon11@example.com | 직업: 콘크리트공
# 이름: 황선영 | 이메일: bagjeongung@example.org | 직업: 보험 및 금융 상품 개발자
# 이름: 박정식 | 이메일: jihyeon50@example.net | 직업: 펄프 및 종이 제조장치 조작원
# 이름: 손현숙 | 이메일: ncoe@example.org | 직업: 장례 상담원 및 장례 지도사
# 이름: 이은지 | 이메일: zhwang@example.org | 직업: 소방관
# 이름: 김현준 | 이메일: jeongsunha@example.org | 직업: 감독 및 기술감독
# 이름: 고성현 | 이메일: seohyeonbag@example.net | 직업: 전산 자료 입력원 및 사무 보조원
# 이름: 장예준 | 이메일: jihu20@example.com | 직업: 건설 및 채굴 기계 운전원
# 이름: 이중수 | 이메일: seonghyeongim@example.org | 직업: 위관급
# 이름: 구성민 | 이메일: gimjeonghyi@example.net | 직업: 학습지 및 방문 교사
# 이름: 황수민 | 이메일: ugim@example.com | 직업: 한의사
# 이름: 김옥순 | 이메일: jeonghomun@example.net | 직업: 육아 도우미
# 이름: 이지원 | 이메일: hwangjieun@example.net | 직업: 철근공
# 이름: 송정자 | 이메일: gojeongsun@example.org | 직업: 냉/난방 관련 설비 조작원
# 이름: 이승현 | 이메일: yujinbag@example.net | 직업: 안내 / 접수 사무원 및 전화교환원
# 이름: 김수진 | 이메일: jiyeonhan@example.org | 직업: 촬영기사
# 이름: 김서윤 | 이메일: yeeungim@example.org | 직업: 관세사
# 이름: 고정남 | 이메일: gimseonyeong@example.org | 직업: 증권 및 외환 딜러
# 이름: 박승현 | 이메일: kna@example.org | 직업: 경영 및 진단 전문가
# 이름: 박진호 | 이메일: sgim@example.org | 직업: 영상/녹화 및 편집 기사
# 이름: 김현준 | 이메일: yeongsu83@example.com | 직업: 실내장식 디자이너
# 이름: 이지은 | 이메일: sujin04@example.com | 직업: 청원 경찰
# 이름: 김영미 | 이메일: seonghyeon46@example.com | 직업: 직조기 및 편직기 조작원
# 이름: 김영희 | 이메일: agim@example.net | 직업: 검표원
# 이름: 유현숙 | 이메일: ogsun07@example.org | 직업: 조경원
# 이름: 임현정 | 이메일: ehan@example.org | 직업: 전기/전자 및 기계 공학 시험원
# 이름: 이서현 | 이메일: eunyeong20@example.com | 직업: 전기 부품 및 제품제조 기계조작원
# 이름: 권은영 | 이메일: hyeonjeong87@example.org | 직업: 판금기 조작원
# 이름: 박지우 | 이메일: igim@example.com | 직업: 주차 관리원 및 안내원
# 이름: 김서윤 | 이메일: sonhyeonjun@example.org | 직업: 큐레이터 및 문화재 보존원
# 이름: 엄정남 | 이메일: icaeweon@example.net | 직업: 제화원
# 이름: 윤선영 | 이메일: jeongsun90@example.net | 직업: 웹 개발자
# 이름: 이수민 | 이메일: rbae@example.org | 직업: 보건의료관련 관리자
# 이름: 박순옥 | 이메일: jaehona@example.org | 직업: 경영 및 진단 전문가
# 이름: 이정순 | 이메일: geonugim@example.net | 직업: 매표원 및 복권 판매원
# 이름: 남건우 | 이메일: ojunho@example.com | 직업: 택시 운전원
# 이름: 김광수 | 이메일: yeongsu45@example.org | 직업: 한복 제조원
# 이름: 서정훈 | 이메일: gimmijeong@example.org | 직업: 가수 및 성악가
# 이름: 박정남 | 이메일: yeongceol48@example.com | 직업: 건설 및 광업기계 설치 및 정비원
# 이름: 박순자 | 이메일: yanghyeonsug@example.org | 직업: 기타 공학관련 기술자 및 시험원
# 이름: 류승현 | 이메일: iseoyun@example.org | 직업: 결혼 상담원 및 웨딩플래너
# 이름: 오민수 | 이메일: borami@example.net | 직업: 배우 및 모델
# 이름: 홍진호 | 이메일: gseo@example.com | 직업: 보험 심사원 및 사무원
# 이름: 이서연 | 이메일: di@example.com | 직업: 가스/에너지 기술자 및 연구원
# 이름: 하병철 | 이메일: ujin68@example.org | 직업: 경찰관
# 이름: 최정순 | 이메일: qgim@example.com | 직업: 조적공 및 석재 부설원
# 이름: 황경희 | 이메일: jeongsuni@example.net | 직업: 바닥재 시공원
# 이름: 김영미 | 이메일: pgim@example.org | 직업: 안마사
# 이름: 문현지 | 이메일: ojang@example.com | 직업: 용접원
# 이름: 김진우 | 이메일: yeongceol29@example.org | 직업: 기타 건설관련 기능 종사원
# 이름: 윤옥자 | 이메일: jiyeon35@example.org | 직업: 주차 관리원 및 안내원
# 이름: 이영수 | 이메일: seojuni@example.net | 직업: 결혼 상담원 및 웨딩플래너
# 이름: 곽민재 | 이메일: anyeongsig@example.com | 직업: 문화/예술/디자인 및 영상관련 관리자
# 이름: 이순옥 | 이메일: doyun77@example.com | 직업: 물품이동 장비 조작원
# 이름: 최도현 | 이메일: areumgim@example.org | 직업: 경리 사무원
# 이름: 황재현 | 이메일: gyeongsu43@example.com | 직업: 시민 단체 활동가
# 이름: 최옥자 | 이메일: seoyeong41@example.net | 직업: 환경공학 기술자 및 연구원
# 이름: 이영식 | 이메일: yunseo33@example.com | 직업: 수금원
# 이름: 김정남 | 이메일: hyeonu31@example.net | 직업: 국악 및 전통예능인
# 이름: 윤영숙 | 이메일: ti@example.org | 직업: 대학 교육조교
# 이름: 이준혁 | 이메일: jihun31@example.org | 직업: 이용사
# 이름: 박지우 | 이메일: seunghyeongang@example.com | 직업: 건축 석공
# 이름: 손도현 | 이메일: gimjeongsun@example.net | 직업: 환경공학 시험원
# 이름: 이영수 | 이메일: ybag@example.net | 직업: 버스 운전원
# 이름: 허선영 | 이메일: junseoyang@example.com | 직업: 법무사 및 집행관
# 이름: 최영호 | 이메일: hyeonju51@example.org | 직업: 단조원
# 이름: 한준서 | 이메일: seungmin07@example.net | 직업: 보험 및 금융 관리자
# 이름: 안중수 | 이메일: coeminjun@example.org | 직업: 모피 및 가죽의복 제조원
# 이름: 김아름 | 이메일: gimjinu@example.net | 직업: 성직자
# 이름: 윤영미 | 이메일: pi@example.org | 직업: 시민 단체 활동가
# 이름: 박민석 | 이메일: gimhaeun@example.com | 직업: 외선전공
# 이름: 나미영 | 이메일: yunseocoe@example.com | 직업: 자동차 영업원
# 이름: 주경자 | 이메일: sangceolryu@example.com | 직업: 출판물 전문가
# 이름: 장지현 | 이메일: gimgwangsu@example.com | 직업: 정부 및 공공 행정 전문가
# 이름: 장영호 | 이메일: namseohyeon@example.com | 직업: 정육원 및 도축원
# 이름: 이미경 | 이메일: suminbag@example.com | 직업: 영상 및 관련 장비 설치 및 수리원
# 이름: 이민지 | 이메일: gimjinu@example.net | 직업: 주조원
# 이름: 이은경 | 이메일: coejeonghun@example.net | 직업: 고무 및 플라스틱 제품 조립원
# 이름: 오현준 | 이메일: gimjihye@example.net | 직업: 법무사 및 집행관
# 이름: 김민수 | 이메일: ei@example.org | 직업: 통신공학 기술자 및 연구원
# 이름: 최은지 | 이메일: gimbyeongceol@example.net | 직업: 철도 및 전동차 기관사
# 이름: 박순자 | 이메일: gimseonghun@example.net | 직업: 기술 영업원
# 이름: 심서준 | 이메일: miyeongryu@example.com | 직업: 금속가공 기계조작원
# 이름: 양미영 | 이메일: gimjeonghun@example.net | 직업: 사진기자 및 사진가
# 이름: 진숙자 | 이메일: amun@example.com | 직업: 기타 여가 및 스포츠 관련 종사원
# 이름: 노영길 | 이메일: yeeun07@example.org | 직업: 환경공학 시험원
# 이름: 이혜진 | 이메일: yeeunju@example.org | 직업: 섀시 조립 및 설치원
# 이름: 고현우 | 이메일: zgim@example.net | 직업: 금속기계부품 조립원
# 이름: 허지영 | 이메일: pgim@example.com | 직업: 섬유공학 기술자 및 연구원
# 이름: 송하은 | 이메일: minseog02@example.net | 직업: 정육원 및 도축원
# 이름: 고영자 | 이메일: unam@example.com | 직업: 생산 및 품질 관리 사무원
# 이름: 송시우 | 이메일: wgim@example.net | 직업: 감독 및 기술감독
# 이름: 김현숙 | 이메일: ccoe@example.org | 직업: 관세행정 사무원
# 이름: 윤지훈 | 이메일: iyeonghyi@example.net | 직업: 기타 음식서비스 종사원
# 이름: 김예지 | 이메일: wi@example.com | 직업: 기타 자동차 운전원
# 이름: 윤민재 | 이메일: juweon57@example.net | 직업: 의회의원/고위공무원 및 공공단체임원
# 이름: 김은경 | 이메일: xi@example.net | 직업: 자동차 영업원
# 이름: 한서현 | 이메일: seojun75@example.com | 직업: 정육원 및 도축원
# 이름: 이예준 | 이메일: nbag@example.org | 직업: 단조원
# 이름: 조정식 | 이메일: gimjiyeong@example.com | 직업: 방수공
# 이름: 송재호 | 이메일: jeonghungim@example.org | 직업: 정육원 및 도축원
# 이름: 김진우 | 이메일: myeongjagim@example.org | 직업: 기타 건설/전기 및 생산 관련 관리자
# 이름: 장민서 | 이메일: yeongjasong@example.org | 직업: 곡물가공제품 기계 조작원
# 이름: 이종수 | 이메일: ujang@example.org | 직업: 제관기 조작원
# 이름: 오영식 | 이메일: gimyeongsun@example.org | 직업: 건설 및 광업기계 설치 및 정비원
# 이름: 김하윤 | 이메일: qyu@example.net | 직업: 선박 및 열차 객실승무원
# 이름: 박영진 | 이메일: minseogi@example.org | 직업: 판금원
# 이름: 이광수 | 이메일: seonyeong93@example.net | 직업: 양식 주방장 및 조리사
# 이름: 남성현 | 이메일: coejia@example.com | 직업: 오락시설 서비스원
# 이름: 김유진 | 이메일: dseong@example.com | 직업: 배관 세정원 및 방역원
# 이름: 이서윤 | 이메일: jiajo@example.net | 직업: 보조 교사 및 기타 교사
# 이름: 박도현 | 이메일: yeongceolyun@example.org | 직업: 인문과학 연구원
# 이름: 김건우 | 이메일: baejunseo@example.net | 직업: 스포츠 및 레크레이션 강사
# 이름: 고지민 | 이메일: miyeonggim@example.org | 직업: 제관원
# 이름: 김준영 | 이메일: hbag@example.org | 직업: 자동조립라인 및 산업용 로봇 조작원
# 이름: 이현준 | 이메일: gimjiyeon@example.org | 직업: 세탁원 및 다림질원
# 이름: 배정희 | 이메일: yeongja54@example.org | 직업: 일식 주방장 및 조리사
# 이름: 배승현 | 이메일: hongyeongmi@example.com | 직업: 공업기계 설치 및 정비원
# 이름: 김유진 | 이메일: yujuweon@example.org | 직업: 냉/난방 관련 설비 조작원
# 이름: 김준서 | 이메일: ao@example.net | 직업: 선박 정비원
# 이름: 신영철 | 이메일: bagareum@example.com | 직업: 청원 경찰
# 이름: 서은서 | 이메일: guyeonghwan@example.org | 직업: 보건의료관련 관리자
# 이름: 이진호 | 이메일: ybag@example.com | 직업: 배관 세정원 및 방역원
# 이름: 조현정 | 이메일: wgim@example.org | 직업: 자연과학 연구원
# 이름: 박현숙 | 이메일: gimdonghyeon@example.com | 직업: 재단사
# 이름: 김정희 | 이메일: sujini@example.net | 직업: 사진인화 및 현상기 조작원
# 이름: 이유진 | 이메일: jeongho06@example.net | 직업: 선박 및 열차 객실승무원
# 이름: 김현지 | 이메일: gwagyeonggil@example.org | 직업: 기타 이미용/예식 및 의료보조 서비스 종사원
# 이름: 김영길 | 이메일: jeonghungim@example.net | 직업: 식품공학 기술자 및 연구원
# 이름: 최서현 | 이메일: anjuweon@example.net | 직업: 건설 및 광업 관련 관리자
# 이름: 김지훈 | 이메일: gyeonghyi63@example.net | 직업: 건설 및 광업 관련 관리자
# 이름: 최우진 | 이메일: gimseongmin@example.org | 직업: 승강기 설치 및 정비원
# 이름: 김건우 | 이메일: ijiyeon@example.net | 직업: 세탁원 및 다림질원
# 이름: 주지훈 | 이메일: jongsubag@example.org | 직업: 기자 및 논설위원
# 이름: 박서현 | 이메일: gyeongsu68@example.org | 직업: 광원/채석원 및 석재 절단원
# 이름: 최춘자 | 이메일: eunju70@example.net | 직업: 여행 사무원
# 이름: 고윤서 | 이메일: jaehyeon26@example.com | 직업: 곡식작물 재배원
# 이름: 오승민 | 이메일: gyeonghyi92@example.com | 직업: 웨이터
# 이름: 김정식 | 이메일: siu25@example.com | 직업: 기타 음식서비스 종사원
# 이름: 김혜진 | 이메일: fjo@example.org | 직업: 토목공학 기술자
# 이름: 송성민 | 이메일: ijeongsu@example.org | 직업: 여행상품 개발자
# 이름: 이정웅 | 이메일: yejun15@example.net | 직업: 냉동/냉장 /공조기 설치 및 정비원
# 이름: 안예진 | 이메일: junseogo@example.org | 직업: 지휘자/작곡가 및 연주가
# 이름: 김성민 | 이메일: rhong@example.com | 직업: 음식서비스관련 관리자
# 이름: 김민서 | 이메일: pjeong@example.com | 직업: 기술 및 기능계 강사
# 이름: 박민지 | 이메일: tryu@example.com | 직업: 정부행정 관리자
# 이름: 한지혜 | 이메일: egim@example.net | 직업: 텔레마케터
# 이름: 장준혁 | 이메일: gimjieun@example.net | 직업: 초등학교 교사
# 이름: 최보람 | 이메일: agim@example.org | 직업: 통신/방송 및 인터넷 케이블 설치 및 수리원
# 이름: 이수빈 | 이메일: yeonghyi55@example.org | 직업: 보험 설계사 및 간접투자증권 판매인
# 이름: 김중수 | 이메일: ebag@example.com | 직업: 기타 연극/영화 및 영상 관련 종사자
# 이름: 박지연 | 이메일: gimeunseo@example.org | 직업: 세탁관련 기계조작원
# 이름: 강미경 | 이메일: hongjeongsun@example.net | 직업: 기타 스포츠 및 레크레이션 관련 전문가
# 이름: 김상현 | 이메일: gyeongja48@example.com | 직업: 기타 이미용/예식 및 의료보조 서비스 종사원
# 이름: 김준호 | 이메일: bagseoyeon@example.net | 직업: 건설 배관공
# 이름: 안지영 | 이메일: eungyeong75@example.net | 직업: 섬유공학 기술자 및 연구원
# 이름: 김옥자 | 이메일: oseoyeon@example.net | 직업: 임산물채취 및 기타 임업 관련 종사원
# 이름: 황영길 | 이메일: zsim@example.com | 직업: 혼례 종사원
# 이름: 이지우 | 이메일: ban@example.org | 직업: 신발제조기 조작원 및 조립원
# 이름: 황진호 | 이메일: yeongsungang@example.net | 직업: 임산물채취 및 기타 임업 관련 종사원
# 이름: 김영환 | 이메일: yujini@example.org | 직업: 철도 기관차 및 전동차 정비원
# 이름: 김보람 | 이메일: gimjeongsig@example.org | 직업: 무용가 및 안무가
# 이름: 박현숙 | 이메일: jeongsug27@example.net | 직업: 김치 및 밑반찬 제조 종사원
# 이름: 이현준 | 이메일: subin16@example.com | 직업: 금형원
# 이름: 박경숙 | 이메일: joseoyeon@example.org | 직업: 계기 검침원 및 가스점검원
# 이름: 이채원 | 이메일: jeonghocoe@example.com | 직업: 정부 및 공공 행정 전문가
# 이름: 김미경 | 이메일: ugim@example.org | 직업: 사회복지사
# 이름: 윤순자 | 이메일: abaeg@example.com | 직업: 제품 및 광고 영업원
# 이름: 송진우 | 이메일: yeonghyii@example.net | 직업: 주차 관리원 및 안내원
# 이름: 이유진 | 이메일: seoyeongim@example.net | 직업: 건설 및 광업기계 설치 및 정비원
# 이름: 이동현 | 이메일: yeongilseo@example.org | 직업: 가구 제조 및 수리원
# 이름: 김은지 | 이메일: yeji37@example.com | 직업: 수의사
# 이름: 윤정웅 | 이메일: jeongsug54@example.org | 직업: 기타 문리/기술 및 예능 강사
# 이름: 박영순 | 이메일: lheo@example.org | 직업: 조명기사 및 영사기사
# 이름: 이준호 | 이메일: minji97@example.net | 직업: 통신/방송 및 인터넷 케이블 설치 및 수리원
# 이름: 박보람 | 이메일: hyeonu35@example.net | 직업: 상/하수도 처리장치 조작원
# 이름: 남영환 | 이메일: jihye77@example.net | 직업: 특수교육 교사
# 이름: 이민서 | 이메일: junseo30@example.net | 직업: 미장공
# 이름: 윤현준 | 이메일: sonyeonghyi@example.net | 직업: 웹 및 멀티미디어 디자이너
# 이름: 이정자 | 이메일: mgim@example.com | 직업: 주조기 조작원
# 이름: 김성수 | 이메일: wan@example.com | 직업: 조세행정 사무원
# 이름: 김영길 | 이메일: jieungim@example.org | 직업: 환경/청소 및 경비 관련 관리자
# 이름: 김은영 | 이메일: bbag@example.net | 직업: 판금원
# 이름: 이영수 | 이메일: wcoe@example.net | 직업: 정부 및 공공 행정 전문가
# 이름: 윤예지 | 이메일: gimeunjeong@example.com | 직업: 건설 및 광업기계 설치 및 정비원
# 이름: 이승현 | 이메일: seonghyeon49@example.com | 직업: 대학 교육조교
# 이름: 이우진 | 이메일: ugim@example.com | 직업: 손해사정인
# 이름: 고시우 | 이메일: seoyeongsig@example.com | 직업: 철도 및 전동차 기관사
# 이름: 류옥자 | 이메일: subin40@example.com | 직업: 기타 공학관련 기술자 및 시험원
# 이름: 이승민 | 이메일: yeongjagwag@example.com | 직업: 교육 관리자
# 이름: 권명자 | 이메일: gweoneunji@example.org | 직업: 조림/영림 및 벌목원
# 이름: 김영진 | 이메일: qhan@example.org | 직업: 단열공
# 이름: 강건우 | 이메일: eungyeongjang@example.com | 직업: 네트워크시스템 개발자
# 이름: 이순자 | 이메일: ygang@example.net | 직업: 구두 미화원
# 이름: 김은서 | 이메일: gimhyeonu@example.net | 직업: 전기공학 기술자 및 연구원
# 이름: 김수빈 | 이메일: siu64@example.net | 직업: 경비원
# 이름: 이현숙 | 이메일: yuseongsu@example.com | 직업: 관세사
# 이름: 노현준 | 이메일: seoyun84@example.net | 직업: 양장 및 양복 제조원
# 이름: 박영식 | 이메일: qgweon@example.org | 직업: 시각 디자이너
# 이름: 남지영 | 이메일: sonseonghun@example.com | 직업: 화가 및 조각가
# 이름: 박경수 | 이메일: jaehyeon37@example.net | 직업: 버스 운전원
# 이름: 윤재호 | 이메일: ci@example.com | 직업: 영상/녹화 및 편집 기사
# 이름: 김명숙 | 이메일: fyang@example.net | 직업: 화물열차 차장 및 관련 종사원
# 이름: 한승민 | 이메일: gimjuweon@example.org | 직업: 판금원
# 이름: 윤정희 | 이메일: dohyeon33@example.net | 직업: 기타 자동차 운전원
# 이름: 윤예지 | 이메일: gimeunju@example.net | 직업: 건설 배관공
# 이름: 백종수 | 이메일: iyeongil@example.com | 직업: 직업 운동선수
# 이름: 김병철 | 이메일: bi@example.net | 직업: 전자공학 기술자 및 연구원
# 이름: 유영순 | 이메일: tgim@example.org | 직업: 건축 목공
# 이름: 서승현 | 이메일: xryu@example.com | 직업: 보험 심사원 및 사무원
# 이름: 김준혁 | 이메일: jinubag@example.net | 직업: 건축 목공
# 이름: 강중수 | 이메일: qgim@example.net | 직업: 간병인
# 이름: 이도윤 | 이메일: jeongsugim@example.com | 직업: 목재 가공관련 기계 조작원
# 이름: 최영희 | 이메일: icoe@example.net | 직업: 채소 및 특용작물 재배원
# 이름: 김정수 | 이메일: jaehyeoni@example.com | 직업: 이용사
# 이름: 이민서 | 이메일: eunyeong17@example.net | 직업: 조경원
# 이름: 황진호 | 이메일: minsugim@example.org | 직업: 무역 사무원
# 이름: 박지훈 | 이메일: dohyeon65@example.net | 직업: 만화가 및 만화영화 작가
# 이름: 박서현 | 이메일: donghyeono@example.org | 직업: 인문과학 연구원
# 이름: 권상호 | 이메일: sangho04@example.org | 직업: 단조원
# 이름: 조지연 | 이메일: donghyeon38@example.com | 직업: 플라스틱제품 생산기 조작원
# 이름: 김선영 | 이메일: nyang@example.net | 직업: 데이터베이스 개발자
# 이름: 박현숙 | 이메일: yeongmi81@example.com | 직업: 건설자재 시험원
# 이름: 김영진 | 이메일: josangho@example.net | 직업: 학습지 및 방문 교사
# 이름: 김민지 | 이메일: thong@example.org | 직업: 채소 및 특용작물 재배원
# 이름: 이서윤 | 이메일: gimseunghyeon@example.com | 직업: 숙박시설 서비스원
# 이름: 김도현 | 이메일: eunjugim@example.net | 직업: 종이제품 생산기 조작원
# 이름: 허은정 | 이메일: jieungim@example.org | 직업: 강구조물 가공원 및 건립원
# 이름: 노건우 | 이메일: kbag@example.com | 직업: 냉/난방 관련 설비 조작원
# 이름: 이미숙 | 이메일: gimdonghyeon@example.org | 직업: 조림/영림 및 벌목원
# 이름: 박성훈 | 이메일: byeongceol67@example.com | 직업: 광석 및 석제품 가공기 조작원
# 이름: 박상훈 | 이메일: yangjeongho@example.org | 직업: 택배원
# 이름: 이수민 | 이메일: vgwag@example.com | 직업: 통역가
# 이름: 손민수 | 이메일: gi@example.com | 직업: 조세행정 사무원
# 이름: 김재현 | 이메일: seoyeongsig@example.net | 직업: 청원 경찰
# 이름: 민영진 | 이메일: igim@example.org | 직업: 안마사
# 이름: 황옥순 | 이메일: junyeongyun@example.org | 직업: 제빵원 및 제과원
# 이름: 김춘자 | 이메일: jihuncoe@example.net | 직업: 시스템 소프트웨어 개발자
# 이름: 김정남 | 이메일: coeseongmin@example.com | 직업: 병무행정 사무원
# 이름: 박영호 | 이메일: jeonghun50@example.com | 직업: 항공기 정비원
# 이름: 박성진 | 이메일: sanghungweon@example.net | 직업: 기타 제조관련 기계 조작원
# 이름: 이영진 | 이메일: yunseoi@example.com | 직업: 산업안전 및 위험 관리원
# 이름: 서예진 | 이메일: pbag@example.com | 직업: 기타 직물 및 신발 관련 기계조작원 및 조립원
# 이름: 이선영 | 이메일: migyeong40@example.net | 직업: 유치원 교사
# 이름: 이영순 | 이메일: hyeonu97@example.org | 직업: 간병인
# 이름: 서지영 | 이메일: seoyeon23@example.net | 직업: 직업 운동선수
# 이름: 최정희 | 이메일: yangjeonghyi@example.com | 직업: 자동차 영업원
# 이름: 오상철 | 이메일: jeonghyii@example.net | 직업: 미장공
# 이름: 배수빈 | 이메일: ggim@example.org | 직업: 문화/예술/디자인 및 영상관련 관리자
# 이름: 김성민 | 이메일: hanjinu@example.net | 직업: 인터넷 판매원
# 이름: 최은서 | 이메일: eungyeong11@example.org | 직업: 주차 관리원 및 안내원
# 이름: 김현주 | 이메일: pi@example.com | 직업: 제화원
# 이름: 김정자 | 이메일: kyun@example.org | 직업: 통신공학 기술자 및 연구원
# 이름: 이건우 | 이메일: hayun02@example.net | 직업: 표백 및 염색 관련 조작원
# 이름: 최채원 | 이메일: seongsuseong@example.com | 직업: 경리 사무원
# 이름: 황중수 | 이메일: yangseonghun@example.org | 직업: 스포츠 및 레크레이션 강사
# 이름: 고은영 | 이메일: ihong@example.com | 직업: 기타 미용관련 서비스 종사원
# 이름: 김은서 | 이메일: jihyecoe@example.net | 직업: 조사 전문가
# 이름: 송영수 | 이메일: jieun02@example.com | 직업: 세탁원 및 다림질원
# 이름: 장경수 | 이메일: obag@example.net | 직업: 단조원
# 이름: 강정훈 | 이메일: sangho36@example.org | 직업: 노점 및 이동 판매원
# 이름: 류현준 | 이메일: yeongsig06@example.com | 직업: 비파괴 검사원
# 이름: 이지우 | 이메일: miyeong23@example.com | 직업: 문리 및 어학 강사
# 이름: 김서준 | 이메일: mijeongbag@example.com | 직업: 외선전공
# 이름: 김예원 | 이메일: gimseojun@example.com | 직업: 건설 및 채굴 기계 운전원
# 이름: 송재현 | 이메일: gimjaehyeon@example.net | 직업: 관세사
# 이름: 고채원 | 이메일: aneungyeong@example.com | 직업: 자동차 조립원
# 이름: 송영환 | 이메일: jungsubag@example.net | 직업: 택시 운전원
# 이름: 이하윤 | 이메일: ygim@example.net | 직업: 관제사
# 이름: 서지훈 | 이메일: sumini@example.com | 직업: 데이터베이스 개발자
# 이름: 장영호 | 이메일: yi@example.net | 직업: 기타 연극/영화 및 영상 관련 종사자
# 이름: 김재호 | 이메일: coejiyeon@example.com | 직업: 상품중개인 및 경매사
# 이름: 서지연 | 이메일: bagareum@example.org | 직업: 결혼 상담원 및 웨딩플래너
# 이름: 오현정 | 이메일: ano@example.org | 직업: 통신/방송 및 인터넷 케이블 설치 및 수리원
# 이름: 김지훈 | 이메일: seonyeonghwang@example.net | 직업: 조림/영림 및 벌목원
# 이름: 서하윤 | 이메일: yunminjae@example.net | 직업: 건설 및 채굴 기계 운전원
# 이름: 김준호 | 이메일: ji@example.org | 직업: 촬영기사
# 이름: 이수민 | 이메일: gimgyeongsu@example.com | 직업: 일식 주방장 및 조리사
# 이름: 최숙자 | 이메일: seonghyeonseo@example.net | 직업: 자재관리 사무원
# 이름: 박광수 | 이메일: fbag@example.net | 직업: 시스템 소프트웨어 개발자
# 이름: 최은경 | 이메일: hyeonjicoe@example.com | 직업: 운송 사무원
# 이름: 김재호 | 이메일: egim@example.net | 직업: 물품이동 장비 조작원
# 이름: 송성훈 | 이메일: jeongsigryu@example.com | 직업: 가수 및 성악가
# 이름: 박은서 | 이메일: yujinmun@example.com | 직업: 농림어업관련 단순 종사원
# 이름: 이재호 | 이메일: yeonghyigang@example.org | 직업: 매장계산원 및 요금정산원
# 이름: 이아름 | 이메일: ijieun@example.com | 직업: 경량 철골공
# 이름: 임정웅 | 이메일: seungmin25@example.com | 직업: 변호사
# 이름: 김현주 | 이메일: hayun38@example.com | 직업: 회계 사무원
# 이름: 오영순 | 이메일: sumin64@example.org | 직업: 가전제품 설치 및 수리원
# 이름: 이진호 | 이메일: jongsui@example.com | 직업: 아나운서 및 리포터
# 이름: 양선영 | 이메일: yangjeongja@example.org | 직업: 신발제조기 조작원 및 조립원
# 이름: 윤재현 | 이메일: tbae@example.com | 직업: 건축 도장공
# 이름: 곽재호 | 이메일: gimjiu@example.net | 직업: 상점 판매원
# 이름: 김민준 | 이메일: seongjincoe@example.net | 직업: 매장계산원 및 요금정산원
# 이름: 김영환 | 이메일: gimseongmin@example.com | 직업: 전문 의사
# 이름: 이종수 | 이메일: ui@example.org | 직업: 초등학교 교사
# 이름: 권영숙 | 이메일: asong@example.com | 직업: 혼례 종사원
# 이름: 장준혁 | 이메일: zbag@example.com | 직업: 기타 배달원
# 이름: 고선영 | 이메일: bagjeonghun@example.org | 직업: 소년보호관 및 교도관
# 이름: 민지은 | 이메일: eunjibag@example.org | 직업: 경찰관
# 이름: 최지후 | 이메일: yeongjin70@example.org | 직업: 운송장비 조립원
# 이름: 김미경 | 이메일: lgo@example.com | 직업: 농업용 및 기타 기계장비 설치 및 정비원
# 이름: 서은지 | 이메일: nhan@example.net | 직업: 인사 및 교육/훈련 사무원
# 이름: 김옥자 | 이메일: hyejin32@example.net | 직업: 애완동물 미용사
# 이름: 김지후 | 이메일: ci@example.net | 직업: 패스트푸드원
# 이름: 서영길 | 이메일: tmun@example.net | 직업: 기타 섬유 및 가죽 관련 기능 종사원
# 이름: 김예원 | 이메일: gwangsu68@example.org | 직업: 의지보조기기사
# 이름: 백우진 | 이메일: jeongung16@example.org | 직업: 제화원
# 이름: 김정식 | 이메일: ci@example.org | 직업: 숙박시설 서비스원
# 이름: 황민석 | 이메일: yeeungim@example.org | 직업: 시멘트 및 광물제품 제조기 조작원
# 이름: 송준서 | 이메일: ji@example.net | 직업: 보험 설계사 및 간접투자증권 판매인
# 이름: 성윤서 | 이메일: sanghuni@example.net | 직업: 주유원
# 이름: 이상호 | 이메일: junhyeog57@example.com | 직업: 영상/녹화 및 편집 기사
# 이름: 류현우 | 이메일: cayeeun@example.org | 직업: 검표원
# 이름: 박지훈 | 이메일: jaehyeongim@example.com | 직업: 식품공학 기술자 및 연구원
# 이름: 윤성훈 | 이메일: hyeonsug26@example.org | 직업: 제품 디자이너
# 이름: 박광수 | 이메일: yeongsug70@example.com | 직업: 혼례 종사원
